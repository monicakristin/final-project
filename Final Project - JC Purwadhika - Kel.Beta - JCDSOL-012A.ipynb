# %% [markdown]
# # **Final Project Purwadhika Kelompok Beta**: e-commerece churn prediction
# ### Beta team: Andhika Prakoso, Emil Supriatna, Monica Kristin

# %% [markdown]
# ![ecommerce_resized.jpg](https://img.freepik.com/free-vector/ecommerce-web-page-concept-illustration_114360-8204.jpg?size=626&ext=jpg&ga=GA1.1.632798143.1704499200&semt=ais)

# %% [markdown]
# ## **Contents**
#
# 1. Business Problem
# 1. Data Understanding
# 1. Data Cleaning
# 1. Data Analysis
# 1. Features Engineering
# 1. Modeling
# 1. Hyperparameter Tuning
# 1. Feature Importance
# 1. Conclusion & Recommendation
# 1. References

# %% [markdown]
# ## A. Business Problem

# %% [markdown]
# ### ***A.1 Konteks***
#
# Dalam persaingan bisnis, mempertahankan pemasukan perusahaan bisa dilakukan melalui cara memperbesar skala bisnis atau menjaga pelanggan agar terus memakai jasa/layanan perusahaan tersebut. Pelanggan yang berhenti menggunakan layanan/jasa perusahaan dapat dikatakan sebagai Customer Churn. [(Forbes)](https://www.forbes.com/advisor/business/churn-rate/).
#
# Kasus kehilangan pelanggan (*Customers Churn*) karena beralih ke pesaing atau memutuskan untuk tidak lagi menggunakan layanan e-commerce akan sangat merugikan, terutama dari sisi pemasukan dan operasional perusahaan. Sebab, mendatangkan pelanggan baru membutuhkan biaya marketing yang tidak sedikit. Secara rata-rata, perusahaan perlu mengeluarkan biaya 4 - 5 kali lebih tinggi untuk mendatangkan pelanggan baru dibandingkan biaya mempertahankan pelanggan lama. Selain itu, terdapat keuntungan lain apabila perusahaan berhasil mempertahankan pelanggan lama, seperti misalnya menjual produk/jasa ke pelanggan lama memiliki rata-rata keberhasilan yang lebih tinggi sebesar 60 - 70% dibandingkan ke pelanggan baru. Puncaknya adalah apabila perusahaan mampu meningkatkan customer retention sebesar 5%, dampaknya yang dihasilkan adalah potensi peningkatan pemasukan hingga 25% [(Outbound)](https://www.outboundengine.com/blog/customer-retention-marketing-vs-customer-acquisition-marketing/#:~:text=Acquiring%20a%20new%20customer%20can,customer%20is%205%2D20%25.)
#
#
# Melihat pentingnya kemampuan menjaga agar pelanggan tidak berpindah ke layanan lain, perusahaan perlu melakukan usaha sebaik mungkin agar membuat pelanggan tetap bertransaksi di layanannya, salah satunya melalui pemberian promo pelanggan. Hanya saja, usaha ini perlu dilakukan secara tepat sasaran agar manfaat yang didapatkan optimal. Oleh karena itu, penting bagi perusahaan untuk dapat mengetahui pelanggan manakah yang memiliki potensi menjadi Churn dan perlu diberikan promo.
#
# Pada kasus ini, sebuah perusahaan e-commerce meminta tim Data Scienctist untuk membuat prediksi yang dapat memberikan deteksi terhadap pelanggan-pelanggan yang akan *churn* dengan cara menganalisis faktor-faktor penyebab *Churn* berdasarkan histori pelanggan-pelanggan sebelumnya. Sehingga, tim promosi dapat menawarkan promosi yang lebih terorientasi pada jenis pelanggan ini sebelum mereka benar-benar *churn*. Promosi ini diharapkan dapat mendorong pelanggan untuk tetap menggunakan layanan e-commerce perusahaan ini.

# %% [markdown]
# ### ***A.2 Problem Statement***
#
#    Tingkat churn pelanggan yang tinggi merupakan masalah signifikan yang dapat menghambat pertumbuhan dan profitabilitas bisnis. Churn mengacu pada persentase pelanggan yang berhenti berbelanja di toko online Anda dalam periode waktu tertentu. Faktanya mempertahankan pelanggan memerlukan upaya dan strategi dari perusahaan. Pelanggan dapat dengan mudah beralih dari satu layanan ecommerce ke layanan ecommerce lainnya, kecuali mereka sudah menemukan kenyamanan pada satu ecommerce. Kehilangan pelanggan ini dapat mengakibatkan penurunan pendapatan perusahaan terutama jika nilai transaksi pelanggan tersebut besar, biaya akuisisi yang tinggi bahkan menurunkan reputasi perusahaan. Pemberian promosi kepada seluruh pelanggan dengan harapan mereka tetap menggunakan layanan ecommerce dapat sangat membebani keuangan perusahaan, namun jika promosi diberikan secara acak juga tidak akan efektif untuk mengatasi *Customer Churn*. Oleh sebab itu, diperlukan prediksi terhadap pelanggan-pelanggan yang cenderung akan *churn*, sehingga promosi dapat diberikan secara efisien dan efektif, terutama dari segi biaya, untuk mengurangi jumlah kasus *Customer Churn* pada perusahaan ecommerce.

# %% [markdown]
# ### ***A.3 Tujuan***
# 1. Mengidentifikasi Karakteristik Pelanggan Churn untuk memahami secara lebih mendalam faktor-faktor yang berkontribusi terhadap Churn
# 2. Memprediksi Pelanggan yang Berpotensi Churn di Masa Mendatang dengan mengembangkan model prediktif yang dapat mengidentifikasi kemungkinan pelanggan yang akan churn dengan akurat sehingga memungkinkan tim promosi untuk mengambil tindakan preventif dengan memberikan penawaran promosi secara akurat

# %% [markdown]
# ### ***A.4 Analytics Approach***
#
# a. Model Prediktif:  Membangun model klasifikasi untuk memprediksi kemungkinan churn pelanggan di masa depan berdasarkan variabel-variabel yang telah diidentifikasi
#
# b. Faktor-Faktor Pengaruh: Menentukan variabel-variabel yang paling mempengaruhi keputusan pelanggan untuk beralih, seperti Cashback, pengalaman pengguna, atau lamanya penggunaan, dengan menggunakan model klasifikasi machine learning untuk penilaian yang lebih akurat

# %% [markdown]
# ### **A.5 Metrics Evaluation**
#
# ![Confussion Matrix](https://miro.medium.com/v2/resize:fit:1218/1*jMs1RmSwnYgR9CsBw-z1dw.png)
#
# - **True Positive (TP)**: Customer diprediksi terjadi *churn* dan kenyataannya terjadi *churn*
# - **True Negative (TN)**: Customer diprediksi tidak terjadi *churn* dan kenyataannya tidak terjadi *churn*
#
# Pada kasus ini, terdapat dua tipe error yang jadi perhatian saat pembuatan model prediksi:
# - **False Positive (FP)**: Customer diprediksi terjadi *churn*, namun pada kenyataannya customer tidak terjadi *churn* <br>
# Konsekuensi: sia-sianya promo yang diberikan, usaha dan biaya terbuang sia-sia
# - **False Negative (FN)**: Customer diprediksi tidak terjadi *churn*, namun pada kenyataannya customer terjadi *churn* <br>
# Konsekuensi: kehilangan pelanggan
#
# **Target**:
# - 0 : Pelanggan tidak *churn*
# - 1 : Pelanggan *churn*
#
# **Metrik evaluasi model:** [(Reference)](https://www.kdnuggets.com/2020/04/performance-evaluation-metrics-classification.html)
#
# - **Presisi** merupakan metrics yang digunakan untuk mengukur ada berapa banyak hasil prediksi suatu kelas yang memang sesuai dengan kenyataan. Kata kunci yang sangat tepat untuk menggambarkan presisi adalah *exactness*.
# - **Recall** merupakan metrics pada metode klasifikasi yang menyatakan seberapa besar persentase kejadian pada kelas positif yang berhasil dideteksi. Kata kunci yang paling tepat menggambarkan recall adalah *completeness*.
# - **F1 score** adalah rataan harmonik dari presisi dan recall. Ketika kita gunakan F1-score dalam pemilihan model machine learning, F1-score dapat menjaga agar model yang kita pilih memiliki nilai recall dan presisi yang seimbang.
# - **Accuracy** adalah salah satu metrik evaluasi yang umum digunakan dalam machine learning untuk mengukur sejauh mana model klasifikasi mampu memprediksi dengan benar kelas atau label dari data uji. Secara sederhana, akurasi mengukur persentase prediksi yang benar dari total jumlah prediksi.
# - **AUC ROC** (Area Under the Curve of the Receiver Operating Characteristic) adalah kinerja keseluruhan dari sebuah model klasifikasi, yang diringkas dari semua ambang klasifikasi yang mungkin, diberikan oleh luas di bawah kurva ROC, atau AUC.
#
#
# Berdasarkan konsekuensi dari False Positive (FP) dan False Negative (FN), tujuan dari model yang kita bangun adalah untuk mengklasifikasikan pelanggan yang akan churn dengan akurat. Meskipun Recall Score sangat cocok untuk memastikan kita mendeteksi sebanyak mungkin pelanggan yang akan churn, kita juga perlu mempertimbangkan presisi agar tidak memberikan terlalu banyak promo yang sia-sia. Oleh karena itu, kita akan menggunakan F1 score, yang merupakan rataan harmonik dari presisi dan recall, untuk menjaga keseimbangan antara keduanya.

# %% [markdown]
# ## B. Data Understanding

# %% [markdown]
# Setelah menyatakan *problem statement*, hal selanjutnya yang dapat dilakukan adalah memahami data yang telah didapatkan sebagai upaya memahami bisnis dan permasalahannya dengan lebih mendalam. Pemahaman data dapat dimulai dengan memahami atribut kolom beserta penjelasannya, kemudian mengimpor terlebih dahulu *library* yang dibutuhkan, dan terakhir menampilkan datasetnya dengan metode *pd.read_excel()*.

# %% [markdown]
# ### **B.1 Library Import**

# %%
# Library
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display

# Feature Engineering
from scipy.stats import shapiro, ttest_ind, chi2_contingency, chi2, mannwhitneyu, spearmanr
from sklearn.pipeline import Pipeline
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
import category_encoders as ce
from sklearn.preprocessing import OrdinalEncoder
from sklearn.feature_selection import SelectFromModel, RFE
from sklearn.preprocessing import OneHotEncoder, RobustScaler

# Model Selection
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV,StratifiedKFold,train_test_split, cross_val_score, RandomizedSearchCV, cross_val_predict
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay,make_scorer, roc_auc_score, roc_curve,  f1_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier, GradientBoostingClassifier, ExtraTreesClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.svm import SVC
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Imbalance Dataset
import imblearn
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import RandomOverSampler, SMOTE



# Ignore Warning
import sys
import warnings
if not sys.warnoptions:
    warnings.simplefilter("ignore")
import logging
logging.getLogger('lightgbm').setLevel(logging.WARNING)

# Saving Model
import pickle

#SHAP
import shap

# Set options to display all rows and columns
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### **B.2 Dataset import & understanding**

# %%
df = pd.read_excel('E Commerce Dataset.xlsx', sheet_name='E Comm')

# %%
atribute = pd.read_excel('E Commerce Dataset.xlsx', sheet_name='Data Dict', header=1).iloc[:,[2,3]]
atribute = atribute.rename(columns={'Discerption': 'Description'})
atribute
# Out:
#                        Variable  \
# 0                    CustomerID
# 1                         Churn
# 2                        Tenure
# 3          PreferredLoginDevice
# 4                      CityTier
# 5               WarehouseToHome
# 6          PreferredPaymentMode
# 7                        Gender
# 8                HourSpendOnApp
# 9      NumberOfDeviceRegistered
# 10             PreferedOrderCat
# 11            SatisfactionScore
# 12                MaritalStatus
# 13              NumberOfAddress
# 14                     Complain
# 15  OrderAmountHikeFromlastYear
# 16                   CouponUsed
# 17                   OrderCount
# 18            DaySinceLastOrder
# 19               CashbackAmount
#
#                                                       Description
# 0                                              Unique customer ID
# 1                                                      Churn Flag
# 2                              Tenure of customer in organization
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5630 entries, 0 to 5629
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CustomerID                   5630 non-null   int64
#  1   Churn                        5630 non-null   int64
#  2   Tenure                       5366 non-null   float64
#  3   PreferredLoginDevice         5630 non-null   object
#  4   CityTier                     5630 non-null   int64
#  5   WarehouseToHome              5379 non-null   float64
#  6   PreferredPaymentMode         5630 non-null   object
#  7   Gender                       5630 non-null   object
#  8   HourSpendOnApp               5375 non-null   float64
#  9   NumberOfDeviceRegistered     5630 non-null   int64
#  10  PreferedOrderCat             5630 non-null   object
#  11  SatisfactionScore            5630 non-null   int64
#  12  MaritalStatus                5630 non-null   object
# ...

# %%
df.head()
# Out:
#    CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0       50001      1     4.0         Mobile Phone         3              6.0
# 1       50002      1     NaN                Phone         1              8.0
# 2       50003      1     NaN                Phone         1             30.0
# 3       50004      1     0.0                Phone         3             15.0
# 4       50005      1     0.0                Phone         1             12.0
#
#   PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 0           Debit Card  Female             3.0                         3
# 1                  UPI    Male             3.0                         4
# 2           Debit Card    Male             2.0                         4
# 3           Debit Card    Male             2.0                         4
# 4                   CC    Male             NaN                         3
#
# ...

# %%
df['CouponUsed'].value_counts()
# Out:
# CouponUsed
# 1.0     2105
# 2.0     1283
# 0.0     1030
# 3.0      327
# 4.0      197
# 5.0      129
# 6.0      108
# 7.0       89
# 8.0       42
# 10.0      14
# 9.0       13
# 11.0      12
# 12.0       9
# 13.0       8
# 14.0       5
# 16.0       2
# 15.0       1
# Name: count, dtype: int64

# %%
display(df.describe().T, df.describe(include='O').T)
# Out:
#                               count          mean          std      min  \
# CustomerID                   5630.0  52815.500000  1625.385339  50001.0
# Churn                        5630.0      0.168384     0.374240      0.0
# Tenure                       5366.0     10.189899     8.557241      0.0
# CityTier                     5630.0      1.654707     0.915389      1.0
# WarehouseToHome              5379.0     15.639896     8.531475      5.0
# HourSpendOnApp               5375.0      2.931535     0.721926      0.0
# NumberOfDeviceRegistered     5630.0      3.688988     1.023999      1.0
# SatisfactionScore            5630.0      3.066785     1.380194      1.0
# NumberOfAddress              5630.0      4.214032     2.583586      1.0
# Complain                     5630.0      0.284902     0.451408      0.0
# OrderAmountHikeFromlastYear  5365.0     15.707922     3.675485     11.0
# CouponUsed                   5374.0      1.751023     1.894621      0.0
# ...

# %%
 df['NumberOfDeviceRegistered'].describe()
# Out:
# count    5630.000000
# mean        3.688988
# std         1.023999
# min         1.000000
# 25%         3.000000
# 50%         4.000000
# 75%         4.000000
# max         6.000000
# Name: NumberOfDeviceRegistered, dtype: float64

# %% [markdown]
# **Overviews:**
# 1. Terdapat 20 kolom yang disertai Deskripsi masing-masing. Kolom pertama merupakan Unit Analysis, yakni Customer ID yang memberikan informasi tentang pelanggan secara unik. Kolom kedua adalah Label, yakni churn yang terdiri dari data 0 (negatif) dan 1 (positif). Sedangkan, 18 kolom lainnya akan berfungsi sebagai Features yang berelasi dengan Label nantinya.
# 2. Pada df.info(), total data berjumlah 5630. Dengan kata lain, kolom yang memiliki Non-Null di bawah jumlah angka tersebut diidentifikasi sebagai Missing Values. Metode .info() ini juga memberikan gambaran Dtype yang belum sesuai untuk beberapa data, misalnya CouponUsed yang seharusnya int malah bertipe float.
# 3. Pada df.describe(), beberapa data diidentifikasi terdistribusi tidak normal atau memiliki outlier, terlihat dari nilai mean yang berdekatan dengan std. Namun, jika dilihat dari nilai mediannya (50%), outlier tersebut tidak ekstrim. Artinya, outlier masih dapat ditoleransi. Meski demikian, perlu analisis lebih jauh untuk mengidentifikasi apakah outlier dapat menimbulkan bias pada hasil prediksi nantinya atau tidak.

# %% [markdown]
# ## C. Exploratory Data Analysis (EDA)

# %% [markdown]
# Pada tahap Exploratory Data Analysis (EDA), kita akan menyelidiki dataset. Proses EDA umumnya akan dilakukan dengan melihat distribusi persebaran dataset, korelasi antar column pada dataset, ataupun pengecekan lain seperti missing values, duplicates, error, dan lain sebagainya. EDA dapat dilakukan dengan pembuatan ringkasan statistik maupun dengan visualisasi grafik untuk memahami data dengan lebih baik.
#
# Mempertimbangkan bahwa tujuan studi kasus ini adalah untuk memprediksi potensi pelanggan terjadi churn/tidak, maka proses EDA akan dibagi berdasarkan kategori pelanggan pada kolom `Churn`. Hal ini bertujuan agar pola yang dihasilkan lebih spesifik untuk tiap kelompok pelanggan Churn/tidak. Kolom-kolom lain akan dijelaskan sebagai pendukung saat melakuian proses EDA.

# %% [markdown]
# ### ***C.1 Proporsi kelompok pelanggan Churn VS Non-Churn***

# %%
count_churn = df['Churn'].value_counts()
count_churn = pd.DataFrame(count_churn)
count_churn.columns = ['Count']
count_churn.index.name = 'Churn'
count_churn
# Out:
#        Count
# Churn
# 0       4682
# 1        948

# %%
# Data persentase churn
percentage_churn = df['Churn'].value_counts(normalize=True) * 100

# Membuat diagram lingkaran
plt.figure(figsize=(8, 6))
plt.pie(percentage_churn, labels=percentage_churn.index, autopct='%1.1f%%', startangle=140, colors=['#00539CFF', '#EEA47FFF'], textprops={'fontsize': 14, 'color': 'white'})
plt.title('Persentase Churn', fontsize=16)
plt.legend(labels=['Non-Churn', 'Churn'], loc='upper right', fontsize=12)
plt.axis('equal')
plt.show()

# %% [markdown]
# Dapat disimpulkan bahwa dataset ini mengalami ketidakseimbangan (imbalance). Ini terlihat dari perbandingan jumlah observasi antara kelas churn dan kelas non-churn dengan proporsi non-churn 83.2% dan churn 16.8%

# %% [markdown]
# ### **C.2 Data distribution**

# %% [markdown]
# #### **Data splitting (Numeric & Categoric)**

# %%
numeric_column = df.select_dtypes(include=['int', 'float']).drop(columns=['CustomerID', 'Churn'])
category_column = df.select_dtypes(include=['object'])

# %%
display(numeric_column.head(),category_column.head(5))
# Out:
#    Tenure  CityTier  WarehouseToHome  HourSpendOnApp  \
# 0     4.0         3              6.0             3.0
# 1     NaN         1              8.0             3.0
# 2     NaN         1             30.0             2.0
# 3     0.0         3             15.0             2.0
# 4     0.0         1             12.0             NaN
#
#    NumberOfDeviceRegistered  SatisfactionScore  NumberOfAddress  Complain  \
# 0                         3                  2                9         1
# 1                         4                  3                7         1
# 2                         4                  3                6         1
# 3                         4                  5                8         0
# 4                         3                  5                3         0
#
#    OrderAmountHikeFromlastYear  CouponUsed  OrderCount  DaySinceLastOrder  \
# 0                         11.0         1.0         1.0                5.0
# ...

# %% [markdown]
# #### **Numeric Data Distribution**

# %%
import math
num_cols = numeric_column.shape[1]
num_rows = math.ceil(num_cols / 3)
plt.figure(figsize=(14, num_rows * 4))
for i, col in enumerate(numeric_column.columns, start=1):
    plt.subplot(num_rows, 3, i)
    sns.histplot(data=df, x=col, hue='Churn', kde=True, palette=['#00539CFF', '#EEA47FFF'], element='step', linewidth=2)
    plt.title(col)
    plt.xlabel('')

plt.tight_layout()
plt.show()

# %% [markdown]
# Overviews:
# - Distribusi kolum numerikal terindikasi skewed positif dimana terjadi penumpukan distribusi data pada range nilai rendah/kecil. Pola distribusi skewed positif ini terjadi di kolom  `Tenure`, `WarehouseToHome`, `NumberOfAddress`,`OrderAmountHikeFromlastYear`,  `CouponUsed`, `OrderCount`,`DaySinceLastOrder`,`CashbackAmount`
#
# - Pola distribusi pada kolom numerikal secara konsisten/identik terjadi antara pelanggan yang Churn ataupun Tidak Churn. Artinya tinggi/rendahnya persebaran data di suatu rentang nilai antara kelompok pelanggan Churn dan Tidak Churn terjadi secara mirip (misal:persebaran tertinggi pada kolom `tenure` adalah nol baik di kelompok Churn maupun Tidak Churn)

# %% [markdown]
# #### **Categoric Data Distribution**

# %%
df_combined = pd.concat([category_column, df['Churn']], axis=1)
fig, axs = plt.subplots(3, 2, figsize=(24, 18), gridspec_kw={'width_ratios': [1, 1]})

# Loop untuk mengisi subplot
for ax, col in zip(axs[:3].flatten(), category_column.columns[:4]):
    sorted_counts = df_combined[col].value_counts().index
    sns.countplot(data=df_combined, x=col, hue='Churn', palette=['#00539CFF', '#EEA47FFF'], dodge=False, order=sorted_counts, ax=ax)
    ax.set_title(col, fontsize=16)
    ax.set_xlabel('', fontsize=14)
    ax.set_ylabel('Count', fontsize=14)
    ax.tick_params(axis='x', rotation=45, labelsize=12)
    ax.tick_params(axis='y', labelsize=12)
    
    # data labels
    for p in ax.patches:
        ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', fontsize=10, color='black', xytext=(0, 5), textcoords='offset points')

# Mengatur subplot terakhir
sorted_counts = df_combined[category_column.columns[4]].value_counts().index
sns.countplot(data=df_combined, x=category_column.columns[4], hue='Churn', palette=['#00539CFF', '#EEA47FFF'], dodge=False, order=sorted_counts, ax=axs[2, 0])
axs[2, 0].set_title(category_column.columns[4], fontsize=16)
axs[2, 0].set_xlabel('', fontsize=14)
axs[2, 0].set_ylabel('Count', fontsize=14)
axs[2, 0].tick_params(axis='x', rotation=45, labelsize=12)
axs[2, 0].tick_params(axis='y', labelsize=12)

# Menghapus subplot yang tidak digunakan
fig.delaxes(axs[2, 1])

# Menampilkan plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Overviews:
# - `Mobile phone` merupakan device yang paling banyak dipakai oleh pelanggan e-commerce, untuk kedua kategori pelanggan Churn dan Tidak Churn.  Namun, terdapat ambiguitas di mana selain Mobile Phone, juga terdapat Phone. Apakah ini 1 item yang sama, atau berbeda? Jika sama, datanya dapat digabung ketika dilakukan pemodelan nantinya.
# - `Debit card` (diikuti oleh `credit card`) menjadi metode pembayaran paling banyak digunakan oleh pelanggan ecommerce, untuk kedua kategori pelanggan Churn dan Tidak Churn. Selain itu, ada indikasi bahwa pelanggan Churn punya kecenderungan menggunakan metode pembayaran `COD`. Terdapat duplikasi, yakni `credit card` seharusnya merujuk pada metode pembayaran yang sama dengan `CC`. Demikian juga, `COD` seharusnya sama dengan `Cash on Delilvery`. Dengan kata lain, kesepakatan nama dapat ditentukan untuk menggabungkan data dengan ciri yang sama tersebut.
# - `Laptop` menjadi barang yang paling banyak dibeli oleh pelanggan Tidak Churn. Sementara itu, pelanggan Churn lebih cenderung berbelanja produk `Mobile Phone` & `Mobile`
# - Pelanggan Tidak Churn merupakan pelanggan yang berstatus `menikah/married`. Sementara itu pelanggan Churn adalah pelangan yang berstatus `Single`.
# - Pelanggan e-commerce didominasi oleh pelanggan laki-laki, baik kelompok Churn maupun Tidak Churn.

# %% [markdown]
# #### ***Normality data distribution***

# %% [markdown]
# Berdasarkan indikasi awal bahwa dataset memiliki persebaran data yang skewed positif. Maka kita akan melakukan uji normalitas data untuk memvalidasi dugaan/temuan awal tersebut.
#
# Uji Normalitas akan menggunakan teknik Shapiro-Wilk dikarenakan beberapa keunggulan dibandingkan teknik lain: [(Reference)](https://www.sciencedirect.com/topics/mathematics/wilk-test) <br>
# - Uji Shapiro-Wilk memberikan nilai p yang akurat bahkan untuk ukuran sampel yang kecil.
# - Uji Shapiro-Wilk tahan terhadap outlier, yang berarti lebih sedikit dipengaruhi oleh nilai-nilai ekstrem dibandingkan dengan beberapa uji normalitas lainnya.
# - Uji Shapiro-Wilk sangat diterima dalam komunitas ilmiah dan direkomendasikan untuk menguji normalitas.

# %%
# Defining significance level
significance_level = 0.05

# Performing Shapiro-Wilk test for normality on each numerical column
normality_test_results = {}

for column in df.select_dtypes(include=['float64', 'int64']):
    stat, p = shapiro(df[column].dropna()) 
    is_significant = p < significance_level
    normality_test_results[column] = {'Statistic': stat, 'p-value': p, 'Significant': is_significant}

# Creating a DataFrame to display the test results
normality_test_df = pd.DataFrame(normality_test_results).T

# Displaying the DataFrame
print(normality_test_df)
# Out:
#                             Statistic p-value Significant
# CustomerID                   0.954907     0.0        True
# Churn                        0.451705     0.0        True
# Tenure                        0.92043     0.0        True
# CityTier                     0.619939     0.0        True
# WarehouseToHome              0.859714     0.0        True
# HourSpendOnApp               0.826565     0.0        True
# NumberOfDeviceRegistered     0.897122     0.0        True
# SatisfactionScore            0.885959     0.0        True
# NumberOfAddress              0.876555     0.0        True
# Complain                     0.565554     0.0        True
# OrderAmountHikeFromlastYear  0.915422     0.0        True
# CouponUsed                   0.728214     0.0        True
# OrderCount                   0.677315     0.0        True
# DaySinceLastOrder            0.899098     0.0        True
# CashbackAmount               0.882676     0.0        True

# %% [markdown]
# Temuan:
# - Hasil uji normalitas terhadap distribusi dataset di tiap kolom numerikal menunjukkan dan memvalidasi bahwa persebaran dataset tidak terdistribusi secara normal yaitu terdistribusi skewed positif.
# - Hal ini berdampak ke pertimbangan tindakan penanganan data dan analisa data lebih lanjut, seperti misal penanganan missing value.

# %% [markdown]
# ### **C.3 Data correlation**

# %% [markdown]
# #### **Data Correlation - Numeric**

# %%
numeric_df = df.select_dtypes(include=['int64', 'float64'])
numeric_df = numeric_df.drop(columns=['CustomerID'])
plt.figure(figsize=(12, 8))
sns.heatmap(numeric_df.corr(method='spearman'), annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Heatmap Korelasi (Spearman)', fontsize=16)
plt.show()

# %% [markdown]
# **Overviews:**
# 1. Uji Korelasi dilakukan untuk melihat seberapa kuat hubungan antarvariabel.
# 2. Method yang digunakan adalah Spearman didasarkan atas distribusi data yang tidak normal.
# 3. Hasil dari Uji Korelasi kemudian disajikan dalam visualisasi Heatmap supaya mudah untuk dibaca.
# 4. Berdasarkan hasil Uji Korelasi yang dilakukan, terlihat bahwa hubungan positif paling besar bernilai 0.47 dan hubungan negatif paling besar bernilai 0.4. Artinya, hubungan yang terbangun antarvariabel dikategorikan lemah.
# 5. Terdapat beberapa variabel berkorelasi dengan label Churn bernilai lebih dari 1 yang dapat dibaca seperti berikut:
#     - Churn >< Complain bernilai 0.25, artinya pelanggan yang mengajukan complain berpotensi untuk Churn.
#     - Churn >< CashbackAmount bernilai -0.17, artinya semakin kecil nilai Cashback yang didapat mendorong pelanggan untuk Churn
#     - Churn >< DaySinceLastOrder bernilai -0.19, artinya pelanggan yang belum lama melakukan order dapat berpotensi Churn
#     - Churn >< Tenure bernilai -0.4, artinya pelanggan baru cenderung akan Churn
# 6. Selain dengan variabel Churn, terdapat korelasi antarvariabel lain yang dapat dieksplorasi sebagai berikut:
#     - OrderCount >< DaySinceLastOrder bernilai 0.47, artinya pelanggan dengan jumlah hari terlama dari order terakhir biasanya pelanggan yang sering order. Berdasarkan informasi ini juga dapat disimpulkan bahwa pelanggan yang baru-baru ini melakukan order memiliki order paling sedikit atau dikatakan sebagai pelanggan baru.
#     - Tenure >< CashbackAmount bernilai 0.45, artinya pelanggan lama cenderung mendapat rata-rata cashback paling banyak dibandingkan pelanggan baru.
#     - OrderCount >< CashbackAmount bernilai 0.4, artinya semakin banyak order yang dilakukan semakin berpeluang mendapat Cashback yang besar.
#     - Fitur OrderCount dan CouponUsed memiliki korelasi 0.73, ini menandakan bahwa perubahan dalam satu variabel cenderung diikuti oleh perubahan dalam variabel lainnya dengan tingkat kepastian yang tinggi.

# %% [markdown]
# #### **Data Correlation - Categoric**

# %%
# category_column
category_encoded = pd.get_dummies(category_column)

# Perform Chi-Square test
chi2, p, _, _ = chi2_contingency(category_encoded)

print("Chi-Square Statistic:", chi2)
print("p-value:", p)
# Out:
# Chi-Square Statistic: 90079.99999999997
# p-value: 1.0

# %% [markdown]
# **Overviews:**
# 1. Uji Korelasi biasanya dilakukan pada data numerik. Namun, penting juga dilakukan Uji Korelasi pada Data Kategori.
# 2. Salah satu caranya adalah dengan metode Chi-Square dengan data yang dikontingensi terlebih dahulu. Pada python, metode ini dilakukan dengan memanfaatkan metode get_dummies(), kemudian dimasukkan ke dalam metode chi2_contingency.
# 3. Nilai Chi-Square Statistic mengindikasikan seberapa besar deviasi yang diamati antara nilai yang diamati dalam data dan nilai yang diharapkan dalam asumsi bahwa tidak ada hubungan antara variabel-variabel yang diuji. Semakin besar nilai Chi-Square, semakin besar deviasi antara observasi aktual dan nilai yang diharapkan.
# 4. Nilai p-value sebesar 1.0 menunjukkan bahwa tidak ada bukti yang cukup untuk menolak hipotesis nol (hipotesis bahwa tidak ada hubungan antara variabel-variabel). Dengan kata lain, tidak ada korelasi yang signifikan antara variabel-variabel yang diuji tersebut.
# 5. Dengan demikian dapat disimpulkan bahwa tidak ada bukti yang cukup untuk menyimpulkan adanya hubungan yang signifikan antara PreferedLoginDevice, PreferredPaymentMode, Gender, PreferedOrderCat, dan MaritalStatus.

# %% [markdown]
# ## D. Data Cleaning

# %% [markdown]
# Setelah mengetahui distribusi dataset, langkah selanjutnya ialah melakukan analisa terhadap kualitas dataset yang dimiliki khususnya pada aspek missing value, outliers, duplikat, label error dan aspek lainnya. Apabila ditemukan data anomali, maka kita akan lakukan penanganan secara langsung pada bagian ini.

# %% [markdown]
# ### **D.1 Missing Value**

# %% [markdown]
# #### **Pengecekan missing value**

# %%
listItem = []

for col in df.columns :
    listItem.append([col,
                     df[col].dtype,
                     df[col].isna().sum(),
                     df[col].nunique(),
                     list(df[col].drop_duplicates().values)])
    
dfDesc = pd.DataFrame(data=listItem, columns=['dataFeatures', 'dataType', 'null','unique', 'uniqueSample'])

df_missing = dfDesc[dfDesc['null']>0]
df_missing
# Out:
#                    dataFeatures dataType  null  unique  \
# 2                        Tenure  float64   264      36
# 5               WarehouseToHome  float64   251      34
# 8                HourSpendOnApp  float64   255       6
# 15  OrderAmountHikeFromlastYear  float64   265      16
# 16                   CouponUsed  float64   256      17
# 17                   OrderCount  float64   258      16
# 18            DaySinceLastOrder  float64   307      22
#
#                                                                                                                                                                                                            uniqueSample
# 2   [4.0, nan, 0.0, 13.0, 11.0, 9.0, 19.0, 20.0, 14.0, 8.0, 18.0, 5.0, 2.0, 30.0, 1.0, 23.0, 3.0, 29.0, 6.0, 26.0, 28.0, 7.0, 24.0, 25.0, 10.0, 15.0, 22.0, 27.0, 16.0, 12.0, 21.0, 17.0, 50.0, 60.0, 31.0, 51.0, 61.0]
# ...

# %%
df_missing['dataFeatures'].unique()
# Out:
# array(['Tenure', 'WarehouseToHome', 'HourSpendOnApp',
#        'OrderAmountHikeFromlastYear', 'CouponUsed', 'OrderCount',
#        'DaySinceLastOrder'], dtype=object)

# %% [markdown]
# **Distribusi data kolom dengan missing value (sebelum impute)**

# %%
columns_with_missing_values = df[['Tenure', 'WarehouseToHome', 'HourSpendOnApp', 'OrderAmountHikeFromlastYear',
                                  'CouponUsed', 'OrderCount', 'DaySinceLastOrder']].isnull()
columns_with_missing_values['Churn'] = df['Churn'] 

pivot_table = columns_with_missing_values.groupby('Churn').sum(); total_counts_per_churn = df['Churn'].value_counts()
pivot_table = (pivot_table.divide(total_counts_per_churn, axis=0)* 100).round(2)
pivot_table = pivot_table.applymap(lambda x: f'{x}%')
pivot_table
# Out:
#       Tenure WarehouseToHome HourSpendOnApp OrderAmountHikeFromlastYear  \
# Churn
# 0      3.91%           3.57%          4.21%                       5.36%
# 1      8.54%           8.86%          6.12%                       1.48%
#
#       CouponUsed OrderCount DaySinceLastOrder
# Churn
# 0           5.3%      5.13%              5.4%
# 1          0.84%       1.9%              5.7%

# %%
columns_with_missing_values_before_impute  = df[['Tenure', 'WarehouseToHome', 'HourSpendOnApp','OrderAmountHikeFromlastYear','CouponUsed','OrderCount', 'DaySinceLastOrder']].copy()
columns_with_missing_values_before_impute['Churn'] = df['Churn'] 
columns_with_missing_values_before_impute.groupby('Churn').describe().round(2).T
# Out:
# Churn                                    0       1
# Tenure                      count  4499.00  867.00
#                             mean     11.50    3.38
#                             std       8.42    5.49
#                             min       0.00    0.00
#                             25%       5.00    0.00
#                             50%      10.00    1.00
#                             75%      17.00    3.00
#                             max      61.00   21.00
# WarehouseToHome             count  4515.00  864.00
#                             mean     15.35   17.13
#                             std       8.48    8.63
#                             min       5.00    5.00
#                             25%       9.00    9.00
#                             50%      13.00   15.00
#                             75%      19.00   24.00
#                             max     127.00   36.00
# HourSpendOnApp              count  4485.00  890.00
# ...

# %%
# Memeriksa sebaran ketiga kolom pada data  asli

missing_handling = df[['Tenure', 'WarehouseToHome', 'HourSpendOnApp', 'OrderAmountHikeFromlastYear',
                        'CouponUsed', 'OrderCount', 'DaySinceLastOrder']].copy()
missing_values = ['Tenure', 'WarehouseToHome', 'HourSpendOnApp', 'OrderAmountHikeFromlastYear',
                        'CouponUsed', 'OrderCount', 'DaySinceLastOrder']

plt.figure(figsize=(12,20))

for i, column in enumerate(missing_values, start=1):
    plt.subplot(8,2,i)
    sns.countplot(x=missing_handling[column])
    plt.xticks(rotation=90)

    plt.tight_layout()
plt.show()

# %% [markdown]
# **Overviews:**
# 1. Terdapat 7 dari 20 kolom yang memiliki Missing Values di dalamnya.
# 2. Ketujuh kolom tersebut memiliki data dengan kategori numerik dengan proporsi Missing Values yang hampir sama, yakni sekitar 5 - 9%. Jumlah data dengan missing value dapat dikatakan cukup banyak dan dikhawatirkan berpengaruh terhadap kualitas hasil model apabila kita hanya sekadar menghapus data dari dataset. Oleh karena itu keputusan yang diambil adalah dengan melakukan penanganan melalui impute.
# 3. Berdasarkan situasi distribusi data yang tidak normal, penanganan impute tidak dapat dilakukan dengan menggunakan mean. Penanganan yang lebih tepat adalah menggunakan median.

# %% [markdown]
# #### **Handling missing value**

# %% [markdown]
# Mengisi missing value dengan median

# %%
missing_handling = df[['Tenure', 'WarehouseToHome', 'HourSpendOnApp', 'OrderAmountHikeFromlastYear',
                        'CouponUsed', 'OrderCount', 'DaySinceLastOrder']].copy()

# Inisialisasi SimpleImputer
imputer = SimpleImputer(strategy='median')

# Fit imputer ke data
imputer.fit(missing_handling[['Tenure', 'WarehouseToHome', 'HourSpendOnApp',
                'OrderAmountHikeFromlastYear', 'CouponUsed', 
                'OrderCount', 'DaySinceLastOrder']])

# Transformasikan data dengan mengisi nilai yang hilang
missing_handling[['Tenure', 'WarehouseToHome', 'HourSpendOnApp',
    'OrderAmountHikeFromlastYear', 'CouponUsed', 
    'OrderCount', 'DaySinceLastOrder']] = imputer.transform(missing_handling[['Tenure', 'WarehouseToHome', 'HourSpendOnApp',
                                                               'OrderAmountHikeFromlastYear', 'CouponUsed', 
                                                               'OrderCount', 'DaySinceLastOrder']])

# %% [markdown]
# Pembuktian bahwa missing value telah diimpute

# %%
missing_handling.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5630 entries, 0 to 5629
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Tenure                       5630 non-null   float64
#  1   WarehouseToHome              5630 non-null   float64
#  2   HourSpendOnApp               5630 non-null   float64
#  3   OrderAmountHikeFromlastYear  5630 non-null   float64
#  4   CouponUsed                   5630 non-null   float64
#  5   OrderCount                   5630 non-null   float64
#  6   DaySinceLastOrder            5630 non-null   float64
# dtypes: float64(7)
# memory usage: 308.0 KB

# %% [markdown]
# **Distribusi data kolom dengan missing value (setelah impute)**

# %%
columns_with_missing_values_after_impute  = missing_handling[['Tenure', 'WarehouseToHome', 'HourSpendOnApp','OrderAmountHikeFromlastYear','CouponUsed','OrderCount', 'DaySinceLastOrder']].copy()
columns_with_missing_values_after_impute['Churn'] = df['Churn'] 
columns_with_missing_values_after_impute.groupby('Churn').describe().round(2).T
# Out:
# Churn                                    0       1
# Tenure                      count  4682.00  948.00
#                             mean     11.40    3.86
#                             std       8.27    5.48
#                             min       0.00    0.00
#                             25%       5.00    0.00
#                             50%      10.00    1.00
#                             75%      17.00    7.00
#                             max      61.00   21.00
# WarehouseToHome             count  4682.00  948.00
#                             mean     15.31   16.86
#                             std       8.33    8.29
#                             min       5.00    5.00
#                             25%       9.00   10.00
#                             50%      14.00   14.00
#                             75%      19.00   22.00
#                             max     127.00   36.00
# HourSpendOnApp              count  4682.00  948.00
# ...

# %% [markdown]
# Setelah melakukan impute dengan Median, mari kita uji apakah proses impute ini merubah distribusi data yang dimiliki oleh kolom yang baru saja kita impute. Harapannya penambahan value tidak merubah distribusi data secara signifikan. Proses yang akan dilakukan adalah:
# 1. Pengujian statistik mean difference antara sebelum dan sesudah impute (menggunakan mann-whitney test -> data tidak terdistribusi normal)
# 1. Perbandingan grafik histogram antara sebelum dan sesudah impute

# %%
mannwhitneyu_results = []

for column in ['Tenure', 'WarehouseToHome', 'HourSpendOnApp', 'OrderAmountHikeFromlastYear', 'CouponUsed', 'OrderCount', 'DaySinceLastOrder']:
    before = columns_with_missing_values_before_impute[column].dropna()
    after = columns_with_missing_values_after_impute[column].dropna()

    stat, p = mannwhitneyu(before, after)
    significance = "Significant" if p < 0.05 else "Not significant"
    
    mannwhitneyu_results.append({'Column': column, 'Statistic': stat, 'p-value': p, 'Significance': significance})

mannwhitneyu_results_df = pd.DataFrame(mannwhitneyu_results)

mannwhitneyu_results_df
# Out:
#                         Column   Statistic   p-value     Significance
# 0                       Tenure  15085622.0  0.905730  Not significant
# 1              WarehouseToHome  15108753.0  0.842186  Not significant
# 2               HourSpendOnApp  15088550.0  0.782549  Not significant
# 3  OrderAmountHikeFromlastYear  15049872.5  0.750599  Not significant
# 4                   CouponUsed  15282562.0  0.331077  Not significant
# 5                   OrderCount  15102185.0  0.899687  Not significant
# 6            DaySinceLastOrder  15079261.5  0.562794  Not significant

# %% [markdown]
# Uji statistik menunjukkan seluruh kolom memiliki p-value > 0.05, yang berarti uji statistik menyatakan bahwa gagal menolak H0. **Artinya hasil impute tidak mengubah data secara signifikan.**

# %%
columns_with_missing_values = ['Tenure', 'WarehouseToHome', 'HourSpendOnApp', 'OrderAmountHikeFromlastYear', 'CouponUsed', 'OrderCount', 'DaySinceLastOrder']

custom_palette = sns.color_palette("husl", len(columns_with_missing_values))

plt.figure(figsize=(15, 10))  # Increase figsize to accommodate 3x3 grid

for i, column in enumerate(columns_with_missing_values, 1):
    plt.subplot(3, 3, i)  # 3 rows, 3 columns, position i
    sns.histplot(data=columns_with_missing_values_before_impute, x=column, kde=True, bins=30, multiple="layer", palette=custom_palette, label='Before Impute')
    sns.histplot(data=columns_with_missing_values_after_impute, x=column, kde=True, bins=30, multiple="layer", palette=custom_palette, label='After Impute')
    plt.title(f'Histogram of {column} before and after impute')
    plt.xlabel(column)
    plt.ylabel('Count')
    plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
#  Melalui pembuktian ini, dapat disimpulkan bahwa proses pengisian missing value dengan Median mampu mengisi value kosong dengan tidak mengubah distribusi/kondisi persebaran data. Oleh karena itu proses penanganan missing value telah selesai dilakukan.

# %%
imputer.fit(df[['Tenure', 'WarehouseToHome', 'HourSpendOnApp',
                'OrderAmountHikeFromlastYear', 'CouponUsed', 
                'OrderCount', 'DaySinceLastOrder']])

# Transformasikan data dengan mengisi nilai yang hilang
df[['Tenure', 'WarehouseToHome', 'HourSpendOnApp',
    'OrderAmountHikeFromlastYear', 'CouponUsed', 
    'OrderCount', 'DaySinceLastOrder']] = imputer.transform(df[['Tenure', 'WarehouseToHome', 'HourSpendOnApp',
                                                               'OrderAmountHikeFromlastYear', 'CouponUsed', 
                                                               'OrderCount', 'DaySinceLastOrder']])

# %% [markdown]
# ### ***D.2 Mengubah Tipe Data***

# %% [markdown]
# Ada beberapa tipe data yang perlu diubah seperti kolom
# `Tenure`, `WarehouseToHome`, `HourSpendOnApp`, `OrderAmountHikeFromlastYear`, `CouponUsed`, `OrderCount`, `DaySinceLastOrder`  : nilai-nilai ini hanya menyatakan bilangan bulat (tanpa fraksi desimal), lebih tepat untuk merepresentasikannya sebagai int.

# %%
# Ubah tipe data kolom yang sesuai
df['Tenure'] = df['Tenure'].astype(int)
df['WarehouseToHome'] = df['WarehouseToHome'].astype(int)
df['HourSpendOnApp'] = df['HourSpendOnApp'].astype(int)
df['OrderAmountHikeFromlastYear'] = df['OrderAmountHikeFromlastYear'].astype(int)
df['CouponUsed'] = df['CouponUsed'].astype(int)
df['OrderCount'] = df['OrderCount'].astype(int)
df['DaySinceLastOrder'] = df['DaySinceLastOrder'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5630 entries, 0 to 5629
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CustomerID                   5630 non-null   int64
#  1   Churn                        5630 non-null   int64
#  2   Tenure                       5630 non-null   int32
#  3   PreferredLoginDevice         5630 non-null   object
#  4   CityTier                     5630 non-null   int64
#  5   WarehouseToHome              5630 non-null   int32
#  6   PreferredPaymentMode         5630 non-null   object
#  7   Gender                       5630 non-null   object
#  8   HourSpendOnApp               5630 non-null   int32
#  9   NumberOfDeviceRegistered     5630 non-null   int64
#  10  PreferedOrderCat             5630 non-null   object
#  11  SatisfactionScore            5630 non-null   int64
#  12  MaritalStatus                5630 non-null   object
# ...

# %% [markdown]
# ### ***D.3 Inconsistent Variable***

# %% [markdown]
# Selanjutnya adalah pengecekan label pada kolom kategori. Label yang tidak konsisten akan mempengaruhi proses pembuatan model karena kolom akan memiliki sejumlah label yang tidak merepresentasikan kondisi aktual. Oleh karena itu, kita perlu tangani terlebih dahulu.

# %% [markdown]
# #### **Pengecekan inconsistent variable**

# %%
plt.figure(figsize=(12,4))
category_df = category_column.drop(['Gender', 'MaritalStatus'], axis=1)

for i, column in enumerate(category_df.columns, start=1):
    plt.subplot(1,3,i)
    counts = category_df[column].value_counts().sort_values(ascending=False)
    sns.countplot(x=category_column[column], order=counts.index)
    plt.xticks(rotation=90)

    plt.tight_layout()
plt.show()

# %% [markdown]
# Overviews:
# - Terdapat error label antara `Mobile Phone` dan `Phone` pada kolom **PreferredLoginDevice**
# - Terdapat error label antara `Cash on Delivery` & `COD`, dan `Credit Card` & `CC` pada kolom **PreferredPaymentMode**
# - Terdapat error label antara `Mobile` dan `Mobile Phone` pada kolom **PreferedOrderCat**

# %% [markdown]
# #### **Penanganan inconsistent variable**

# %% [markdown]
# Untuk setiap label berbeda akan digabung ke label yang lebih besar proporsinya

# %%
mapping_1 = {'Phone': 'Mobile Phone'}
mapping_2 = {'CC': 'Credit Card', 'Cash on Delivery' : 'COD'}
mapping_3 = {'Mobile': 'Mobile Phone'}

df['PreferredLoginDevice'] = df['PreferredLoginDevice'].replace('Phone', 'Mobile Phone')
df['PreferredPaymentMode'] = df['PreferredPaymentMode'].replace({'CC': 'Credit Card', 'Cash on Delivery' : 'COD'})
df['PreferedOrderCat'] = df['PreferedOrderCat'].replace('Mobile', 'Mobile Phone')

# %% [markdown]
# Hasil setelah ditangani

# %%
plt.figure(figsize=(12,4))
category_df = df[['PreferredLoginDevice', 'PreferredPaymentMode', 'PreferedOrderCat']]

for i, column in enumerate(category_df.columns, start=1):
    plt.subplot(1,3,i)
    counts = category_df[column].value_counts().sort_values(ascending=False)
    sns.countplot(x=category_df[column], order=counts.index)
    plt.xticks(rotation=90)

    plt.tight_layout()
plt.show()

# %% [markdown]
# ### ***D.4 Data Duplikat***

# %% [markdown]
# Pengecekan data duplikat diperlukan karena data duplikat berpotensi membuat hasil analisa dan pembuatan model menjadi tidak akurat karena data duplikat bisa saja mengubah distribusi ataupun pola temuan dari dataset yang dimiliki.
# Berhubung dataset memiliki kolom `CustomerID` yang bersifat unique value. Maka indikator utama penentuan duplikasi data akan mengacu pada kolom tersebut.

# %%
duplicated_data = df.duplicated(subset='CustomerID')
print(df[duplicated_data])
# Out:
# Empty DataFrame
# Columns: [CustomerID, Churn, Tenure, PreferredLoginDevice, CityTier, WarehouseToHome, PreferredPaymentMode, Gender, HourSpendOnApp, NumberOfDeviceRegistered, PreferedOrderCat, SatisfactionScore, MaritalStatus, NumberOfAddress, Complain, OrderAmountHikeFromlastYear, CouponUsed, OrderCount, DaySinceLastOrder, CashbackAmount]
# Index: []

# %% [markdown]
# Overiews:
# - Tidak ada data duplikat yang terdeteksi

# %% [markdown]
# ### ***D.5 Drop Kolom CustomerID***

# %% [markdown]
# Kolom CustomerID dihapus karena tidak digunakan dalam analisa data

# %%
# Drop Customer ID
df = df.drop(['CustomerID'], axis=1)

# %%
# Kolom customer ID telah terhapus
df.columns
# Out:
# Index(['Churn', 'Tenure', 'PreferredLoginDevice', 'CityTier',
#        'WarehouseToHome', 'PreferredPaymentMode', 'Gender', 'HourSpendOnApp',
#        'NumberOfDeviceRegistered', 'PreferedOrderCat', 'SatisfactionScore',
#        'MaritalStatus', 'NumberOfAddress', 'Complain',
#        'OrderAmountHikeFromlastYear', 'CouponUsed', 'OrderCount',
#        'DaySinceLastOrder', 'CashbackAmount'],
#       dtype='object')

# %% [markdown]
# ### ***D.6 Analisis Multikolinearitas***

# %% [markdown]
# Pada pengecekan kolom OrderCount dan CouponUsed memiliki korelasi yang kuat yaitu 0.73

# %%
# Uji VIF (Variance Inflation Factor)
X = df[['OrderCount', 'CouponUsed']] 
vif_data = pd.DataFrame()
vif_data["Feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))]
vif_data
# Out:
#       Feature      VIF
# 0  OrderCount  2.97682
# 1  CouponUsed  2.97682

# %% [markdown]
#  Nilai VIF yang relatif rendah menunjukkan bahwa multicollinearity (kolerasi tinggi antar variabel independen) tidak terlalu signifikan antara variabel tersebut.

# %% [markdown]
# ### ***D.7 Handling Outlier***

# %% [markdown]
# Pengecekan data *outlier*/anomali perlu dilakukan untuk memastikan bahwa dataset terdiri dari nilai-nilai yang tidak outliers. Atau apabila pun memiliki outlier masih dalam rentang yang masuk akal/logis. Data outlier yang tidak masuk akal dapat meningkatkan varian kesalahan dan mengurangi kekuatan uji statistik yang dilakukan. Hal ini juga dapat menyebabkan bias dan mempengaruhi hasil perkiraan, serta dapat memengaruhi asumsi dasar pemodelan nantinya.
#
#
# Untuk pengecekan outliers, kita akan menggunakan penghitungan Interquartile Range Score (IQR). Data yang jatuh diluar range IQR dapat dikatakan sebagai data anomali (below Q1 - 1.5 * IQR or above Q3 + 1.5 * IQR)

# %% [markdown]
# **Jumlah data yang terindikasi outliers di tiap kolom**

# %%
numerical_columns = df.select_dtypes(exclude=['object']).drop(columns=['Churn']).columns


# Calculating IQR and outlier count for each numerical column
outlier_analysis = []

for column in numerical_columns:
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    num_outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)].shape[0]
    
    outlier_analysis.append({
        "Column": column,
        "Q1": Q1,
        "Q3": Q3,
        "IQR": IQR,
        "Lower Bound": lower_bound,
        "Upper Bound": upper_bound,
        "Number of Outliers": num_outliers
    })

# Creating a DataFrame for the analysis
outlier_analysis_df = pd.DataFrame(outlier_analysis)
outlier_analysis_df.set_index("Column", inplace=True)
outlier_analysis_df
# Out:
#                                  Q1        Q3      IQR  Lower Bound  \
# Column
# Tenure                         3.00   15.0000  12.0000    -15.00000
# CityTier                       1.00    3.0000   2.0000     -2.00000
# WarehouseToHome                9.00   20.0000  11.0000     -7.50000
# HourSpendOnApp                 2.00    3.0000   1.0000      0.50000
# NumberOfDeviceRegistered       3.00    4.0000   1.0000      1.50000
# SatisfactionScore              2.00    4.0000   2.0000     -1.00000
# NumberOfAddress                2.00    6.0000   4.0000     -4.00000
# Complain                       0.00    1.0000   1.0000     -1.50000
# OrderAmountHikeFromlastYear   13.00   18.0000   5.0000      5.50000
# CouponUsed                     1.00    2.0000   1.0000     -0.50000
# OrderCount                     1.00    3.0000   2.0000     -2.00000
# DaySinceLastOrder              2.00    7.0000   5.0000     -5.50000
# CashbackAmount               145.77  196.3925  50.6225     69.83625
#
# ...

# %% [markdown]
# Overviews:
# - Hasil penghitungan IQR menunjukkan bahwa terdapat sejumlah kolom yang memiliki data outliers yang cukup tinggi seperti `NumberOfDeviceRegistered`, `CouponUsed`, `OrderCount`, `CashbackAmount`.
# - Apabila pengecekan hanya didasari oleh penilaian skor IQR, maka dataset ini sudah bisa dikatakan outliers yang perlu untuk diremove dalam dataset untuk menjaga kualitas data permodelan nanti. Namun, sebelum memgambil keputusan ini, mari kita cek lebih lanjut apakah outliers-nya masih masuk akal/logis atau tidak. Apabila masih logis, maka data-data tersebut masih layak untuk dipertahankan dalam dataset.
#
# Pengecekan lebih lanjut akan menggunakan visualisasi boxplot graph. Visualisasi akan membantu penentuan apakah data outliers masih dalam rentang yang masuk akal/logis atau tidak.

# %% [markdown]
# **Penanganan outlier pada kolom Tenure**

# %%
# Data Distribusion use method boxplot()
plt.figure(figsize=(5, 3))
sns.boxplot(x=df['Tenure'])
plt.title('Boxplot Tenure')
plt.tight_layout()
plt.show()

# %% [markdown]
# Berdasarkan pengecekan boxplot pada kolom `Tenure`, terlihat bahwa data outlier berada pada rentang nilai 50 - 60. Data outlier ini terindikasi tidak logis dengan pertimbangan bahwa tidak ada data outlier lain setelah nilai 31. Hal ini cukup mengindikasikan bahwa data outlier ini dapat dikatakan data error. Keputusan tindakan outlier pada kolom ini adalah **dihapus** dalam dataset.

# %%
# Filtering the DataFrame to remove rows outliers
column_name = 'Tenure'
df = df[df[column_name] < 50]

# Data Distribusion use method boxplot()
plt.figure(figsize=(5, 3))
sns.boxplot(x=df['Tenure'])
plt.title('Boxplot Tenure')
plt.tight_layout()
plt.show()

# %% [markdown]
# Data outlier pada kolom Tenure telah dihapus

# %% [markdown]
# **Penanganan outlier pada kolom WarehouseToHome**

# %%
# Data Distribusion use method boxplot()
plt.figure(figsize=(5, 3))
sns.boxplot(x=df['WarehouseToHome'])
plt.title('Boxplot WarehouseToHome')
plt.tight_layout()
plt.show()

# %% [markdown]
# Berdasarkan pengecekan boxplot pada kolom `WarehouseToHome`, terlihat bahwa data outlier berada pada rentang nilai 120 KM dari warehouse. Data outlier ini terindikasi tidak logis dengan pertimbangan bahwa tidak ada data outlier lain setelah nilai 38. Hal ini cukup mengindikasikan bahwa data outlier ini dapat dikatakan data error. Keputusan tindakan outlier pada kolom ini adalah **dihapus** dalam dataset.

# %%
# Filtering the DataFrame to remove rows outliers
column_name = 'WarehouseToHome'
df = df[df[column_name] < 120]

# Data Distribusion use method boxplot()
plt.figure(figsize=(5, 3))
sns.boxplot(x=df['WarehouseToHome'])
plt.title('Boxplot WarehouseToHome')
plt.tight_layout()
plt.show()

# %% [markdown]
# Data outlier pada kolom WarehouseToHome telah dihapus

# %% [markdown]
# **Penanganan outlier pada kolom HourSpendOnApp**

# %%
# Data Distribusion use method boxplot()
plt.figure(figsize=(5, 3))
sns.boxplot(x=df['HourSpendOnApp'])
plt.title('Boxplot HourSpendOnApp')
plt.tight_layout()
plt.show()

# %% [markdown]
# Berdasarkan pengecekan boxplot pada kolom `HourSpendOnApp`, terlihat bahwa data outlier berada pada rentang nilai 1 Jam & 5 Jam berada di aplikasi/platform. Mempertimbangkan pemahaman bahwa durasi tersebut masih dalam batas wajar dan sangat mungkin, oleh karena itu data outlier ini masih sangat masuk akal. Keputusan tindakan outlier pada kolom ini adalah **dipertahankan** dalam dataset.

# %% [markdown]
# **Penanganan outlier pada kolom NumberOfDeviceRegistered**

# %%
# Data Distribusion use method boxplot()
plt.figure(figsize=(5, 3))
sns.boxplot(x=df['NumberOfDeviceRegistered'])
plt.title('Boxplot NumberOfDeviceRegistered')
plt.tight_layout()
plt.show()

# %% [markdown]
# Berdasarkan pengecekan boxplot pada kolom `NumberOfDeviceRegistered`, terlihat bahwa data outlier berada pada rentang nilai 1 dan 6 device yang terdaftar. Mempertimbangkan pemahaman bahwa jumlah tersebut masih dalam batas wajar dan sangat mungkin, oleh karena itu data outlier ini masih sangat masuk akal. Keputusan tindakan outlier pada kolom ini adalah **dipertahankan** dalam dataset.

# %% [markdown]
# **Penanganan outlier pada kolom NumberOfAddress**

# %%
# Data Distribusion use method boxplot()
plt.figure(figsize=(5, 3))
sns.boxplot(x=df['NumberOfAddress'])
plt.title('Boxplot NumberOfAddress')
plt.tight_layout()
plt.show()

# %% [markdown]
# Berdasarkan pengecekan boxplot pada kolom `NumberOfAddress`, terlihat bahwa data outlier berada pada rentang nilai 17 - 23 alamat terdaftar. Data outlier ini terindikasi tidak logis dengan pertimbangan bahwa tidak ada data outlier lain setelah nilai 11. Hal ini cukup mengindikasikan bahwa data outlier ini dapat dikatakan data error. Keputusan tindakan outlier pada kolom ini adalah **dihapus** dalam dataset.

# %%
# Filtering the DataFrame to remove rows outliers
column_name = 'NumberOfAddress'
df = df[df[column_name] < 15]

# Data Distribusion use method boxplot()
plt.figure(figsize=(5, 3))
sns.boxplot(x=df['NumberOfAddress'])
plt.title('Boxplot NumberOfAddress')
plt.tight_layout()
plt.show()

# %% [markdown]
# Data outlier pada kolom NumberOfAddress telah dihapus

# %% [markdown]
# **Penanganan outlier pada kolom OrderAmountHikeFromlastYear**

# %%
# Data Distribusion use method boxplot()
plt.figure(figsize=(5, 3))
sns.boxplot(x=df['OrderAmountHikeFromlastYear'])
plt.title('Boxplot OrderAmountHikeFromlastYear')
plt.tight_layout()
plt.show()

# %% [markdown]
# Berdasarkan pengecekan boxplot pada kolom `OrderAmountHikeFromlastYear`, terlihat bahwa data outlier berada pada rentang nilai 26 jumlah kenaikan order dari tahun lalu. Mempertimbangkan pemahaman bahwa jumlah tersebut masih dalam batas wajar dan mungkin terjadi, oleh karena itu data outlier ini masih masuk akal. Keputusan tindakan outlier pada kolom ini adalah **dipertahankan** dalam dataset.

# %% [markdown]
# **Penanganan outlier pada kolom CouponUsed**

# %%
# Data Distribusion use method boxplot()
plt.figure(figsize=(5, 3))
sns.boxplot(x=df['CouponUsed'])
plt.title('Boxplot CouponUsed')
plt.tight_layout()
plt.show()

# %% [markdown]
# Berdasarkan pengecekan boxplot pada kolom `CouponUsed`, terlihat bahwa data outlier berada pada rentang nilai 4 - 16 jumlah kupon yang digunakan. Mempertimbangkan pemahaman bahwa jumlah penggunaan kupon tersebut berada dalam batas wajar dan mungkin terjadi, oleh karena itu data outlier ini masih masuk akal. Keputusan tindakan outlier pada kolom ini adalah **dipertahankan** dalam dataset.

# %% [markdown]
# **Penanganan outlier pada kolom OrderCount**

# %%
# Data Distribusion use method boxplot()
plt.figure(figsize=(5, 3))
sns.boxplot(x=df['OrderCount'])
plt.title('Boxplot OrderCount')
plt.tight_layout()
plt.show()

# %% [markdown]
# Berdasarkan pengecekan boxplot pada kolom `OrderCount`, terlihat bahwa data outlier berada pada rentang nilai 6 - 16 jumlah order yang dilakukan pelanggan. Mempertimbangkan pemahaman bahwa jumlah tersebut masih dalam batas wajar dan mungkin terjadi, oleh karena itu data outlier ini masih masuk akal. Keputusan tindakan outlier pada kolom ini adalah **dipertahankan** dalam dataset.

# %% [markdown]
# **Penanganan outlier pada kolom DaySinceLastOrder**

# %%
# Data Distribusion use method boxplot()
plt.figure(figsize=(5, 3))
sns.boxplot(x=df['DaySinceLastOrder'])
plt.title('Boxplot DaySinceLastOrder')
plt.tight_layout()
plt.show()

# %% [markdown]
# Berdasarkan pengecekan boxplot pada kolom `DaySinceLastOrder`, terdapat 3 data outlier cukup ekstrim dari pelanggan yang hari sejak pelanggan terakhir kali melakukan pesanan yang diatas 20 hari. Data ini dihapus karena outlier memiliki rentang cukup jauh dari upperbound dan ada indikasi kesalahan menginput data.

# %%
column_name = 'DaySinceLastOrder'
df = df[df[column_name] < 20]

# Data Distribusion use method boxplot()
plt.figure(figsize=(5, 3))
sns.boxplot(x=df['DaySinceLastOrder'])
plt.title('Boxplot DaySinceLastOrder')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Penanganan outlier pada kolom CashbackAmount**

# %%
# Data Distribusion use method boxplot()
plt.figure(figsize=(5, 3))
sns.boxplot(x=df['CashbackAmount'])
plt.title('Boxplot CashbackAmount')
plt.tight_layout()
plt.show()

# %% [markdown]
# Berdasarkan pengecekan boxplot pada kolom `CashbackAmount`, terlihat bahwa data outlier di bawah lowerbound dan diatas upperbound. Mempertimbangkan pemahaman bahwa jumlah pemberian cashback tersebut masih dalam batas wajar dan mungkin terjadi, oleh karena itu data outlier ini masih masuk akal. Keputusan tindakan outlier pada kolom ini adalah **dipertahankan** dalam dataset.

# %% [markdown]
# ## E.Data Analysis

# %% [markdown]
# Tahapan ini merupakan bagian dari exploratory data analysis (EDA) tahap lanjut dan menekankan pada hubungan antar variabel independen dengan variabel dependennya. Tujuan dari analisis data adalah untuk mengekstrak informasi yang berguna untuk memahami faktor-faktor yang menjadi karakteristik pelanggan Churn.
#
# Format analisa akan berfokus pada deskripsi/distribusi tiap kolom terhadap kolom Churn. Hal ini akan memberikan informasi kita mengenai karakteristik pelanggan Churn di setiap kolom yang dimiliki.
#
#
# Hasil data analisa juga bermanfaat dalam proses pembuatan model, yaitu pada tahap feature selection

# %% [markdown]
# ### ***E.1. Data Preparation***

# %% [markdown]
# #### **Data Splitting**

# %% [markdown]
# Spliting data ini bertujuan untuk mencegah terjadinya data leakage pada data test ketika kita melakukan analisa karakteristik pelanggan Churn/Tidak Churn
# - Data split akan membagi data menjadi tiga kelompok yaitu data training, data validation, dan data test.
# - Proporsi masing-masing kelompok adalah 70:15:15
#
# Analisa data akan dilakukan pada data train&validation

# %% [markdown]
# ![Data split](https://upload.wikimedia.org/wikipedia/commons/thumb/b/bb/ML_dataset_training_validation_test_sets.png/1200px-ML_dataset_training_validation_test_sets.png?20201206114522)

# %% [markdown]
# Nanti pada proses pembuatan model, tiap kelompok datasplit akan dipakai sesuai dengan fase pengembangan model mengacu pada gambar berikut:
#
# ![Data split usage](data:image/png;base64,...)

# %%
# Mengubah Data Numerik non_Binning menjadi Data Kategori
df['CityTier'] = df['CityTier'].replace({1: 'Tier_1', 2 : 'Tier_2', 3 : 'Tier_3'})
df['SatisfactionScore'] = df['SatisfactionScore'].replace({1 : 'Very_Satisfied',
                                                           2 : 'Satisfied',
                                                           3 : 'Neutral',
                                                           4 : 'Dissatisfied',
                                                           5 : 'Highly_Dissatisfied'})
df['Complain'] = df['Complain'].replace({1: 'Complain', 0 : 'non-Complain'})

df['PreferedOrderCat'] = df['PreferedOrderCat'].replace('Laptop & Accessory', 'Laptop & Acc')
df['NumberOfDeviceRegistered'] = df['NumberOfDeviceRegistered'].replace({1 : '1_Device',
                                                           2 : '2_Devices',
                                                           3 : '3_Devices',
                                                           4 : '4_Devices',
                                                           5 : '5_Devices',
                                                           6 : '6_Devices'})

# %%
X = df[['Tenure', 'PreferredLoginDevice', 'CityTier',
       'WarehouseToHome', 'PreferredPaymentMode', 'Gender', 'HourSpendOnApp',
       'NumberOfDeviceRegistered', 'PreferedOrderCat', 'SatisfactionScore',
       'MaritalStatus', 'NumberOfAddress', 'Complain',
       'OrderAmountHikeFromlastYear', 'CouponUsed', 'OrderCount',
       'DaySinceLastOrder', 'CashbackAmount']]
y = df['Churn']

# %%
X_trainval, X_test, y_trainval, y_test = train_test_split(X, y, test_size=0.15, random_state=2020, stratify=y)

display(X_trainval.shape, X_test.shape)
# Out:
# (4774, 18)
# (843, 18)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_trainval, y_trainval, test_size=841, random_state=2020, stratify=y_trainval)

display(X_train.shape, X_val.shape)
# Out:
# (3933, 18)
# (841, 18)

# %% [markdown]
# #### **Create Dataset For Analysis**

# %% [markdown]
# Pembuatan dataset baru menggunakan data train & validation

# %%
training = pd.concat([X_train, y_train], axis=1).copy()
training['group'] = 'Train'

# %%
validasi = pd.concat([X_val, y_val], axis=1).copy()
validasi['group'] = 'Val'

# %%
training['Churn'].value_counts()/3931
# Out:
# Churn
# 0    0.832104
# 1    0.168405
# Name: count, dtype: float64

# %%
validasi['Churn'].value_counts()/843
# Out:
# Churn
# 0    0.830368
# 1    0.167260
# Name: count, dtype: float64

# %%
df_modelling = pd.concat([training, validasi], axis=0).copy()
df_modelling
# Out:
#       Tenure PreferredLoginDevice CityTier  WarehouseToHome  \
# 1418       5         Mobile Phone   Tier_1                6
# 2410      28         Mobile Phone   Tier_1               10
# 3853      11         Mobile Phone   Tier_1               17
# 3512       8             Computer   Tier_1                9
# 2129      11         Mobile Phone   Tier_1               23
# ...      ...                  ...      ...              ...
# 4366       1         Mobile Phone   Tier_1               12
# 112       25             Computer   Tier_3                8
# 3738       8         Mobile Phone   Tier_3               10
# 2255       9         Mobile Phone   Tier_1                7
# 4564       2         Mobile Phone   Tier_1               24
#
#      PreferredPaymentMode  Gender  HourSpendOnApp NumberOfDeviceRegistered  \
# 1418           Debit Card    Male               3                3_Devices
# 2410           Debit Card    Male               1                3_Devices
# ...

# %%
listItem = []

for col in df_modelling.drop('group', axis=1).columns:
    listItem.append([
        col,
        df_modelling[col].dtype,
        df_modelling[col].isna().sum(),
        round(df_modelling[col].isna().sum() / len(df_modelling[col]) * 100, 2),
        df_modelling[col].nunique(),
        list(df_modelling[col].drop_duplicates().values),
        df_modelling[col].min(),
        df_modelling[col].max()
    ])

dfDesc = pd.DataFrame(data=listItem, columns=['dataFeatures', 'dataType', 'null', 'nullPct',
                                              'unique', 'uniqueSample', 'min', 'max'])

dfDesc
# Out:
#                    dataFeatures dataType  null  nullPct  unique  \
# 0                        Tenure    int32     0      0.0      32
# 1          PreferredLoginDevice   object     0      0.0       2
# 2                      CityTier   object     0      0.0       3
# 3               WarehouseToHome    int32     0      0.0      32
# 4          PreferredPaymentMode   object     0      0.0       5
# 5                        Gender   object     0      0.0       2
# 6                HourSpendOnApp    int32     0      0.0       6
# 7      NumberOfDeviceRegistered   object     0      0.0       6
# 8              PreferedOrderCat   object     0      0.0       5
# 9             SatisfactionScore   object     0      0.0       5
# 10                MaritalStatus   object     0      0.0       3
# 11              NumberOfAddress    int64     0      0.0      11
# 12                     Complain   object     0      0.0       2
# 13  OrderAmountHikeFromlastYear    int32     0      0.0      16
# ...

# %% [markdown]
# ### ***Uji Signifikansi Perbedaan Fitur antara Kelompok Churn dan Non Churn***

# %%
#Numerik
churned = df_modelling[df_modelling['Churn'] == 1]
not_churned = df_modelling[df_modelling['Churn'] == 0]

mean_test_results = {}

# Loop through columns and perform Mann-Whitney U test
for column in df_modelling.select_dtypes(include=['float64', 'int64', 'int32']):
    if column != 'Churn':
        stat, p = mannwhitneyu(churned[column].dropna(), not_churned[column].dropna())
        mean_test_results[column] = p

# Create DataFrame from mean test results
mean_test_df = pd.DataFrame(mean_test_results.items(), columns=['Feature', 'p-value'])

# Add interpretation column
alpha = 0.05
mean_test_df['Interpretation'] = mean_test_df['p-value'].apply(lambda x: 'Significant' if x < alpha else 'Not significant')

# Display the DataFrame
mean_test_df
# Out:
#                        Feature        p-value   Interpretation
# 0                       Tenure  8.415758e-150      Significant
# 1              WarehouseToHome   1.611558e-08      Significant
# 2               HourSpendOnApp   2.892927e-01  Not significant
# 3              NumberOfAddress   7.878121e-02  Not significant
# 4  OrderAmountHikeFromlastYear   1.669478e-01  Not significant
# 5                   CouponUsed   2.505149e-01  Not significant
# 6                   OrderCount   6.544093e-03      Significant
# 7            DaySinceLastOrder   6.321473e-36      Significant
# 8               CashbackAmount   5.881441e-35      Significant

# %%
#Kategorik
chi_square_results = {}

# Loop through categorical columns (excluding 'CustomerID') and perform chi-square test
for column in df_modelling.drop('group', axis=1).select_dtypes(include=['object']).columns:
    if column != 'CustomerID':
        contingency_table = pd.crosstab(df_modelling[column], df_modelling['Churn'])
        chi2, p, dof, expected = chi2_contingency(contingency_table)
        chi_square_results[column] = {'Chi-square': chi2, 'p-value': p}

# Create DataFrame from chi-square test results
chi_square_results_df = pd.DataFrame(chi_square_results).T

# Add interpretation column based on significance level (alpha)
alpha = 0.05
chi_square_results_df['Interpretation'] = chi_square_results_df['p-value'].apply(lambda x: 'Significant' if x < alpha else 'Not significant')

# Display the DataFrame
chi_square_results_df
# Out:
#                           Chi-square       p-value Interpretation
# PreferredLoginDevice       13.556989  2.314281e-04    Significant
# CityTier                   29.511291  3.905751e-07    Significant
# PreferredPaymentMode       40.923221  2.788032e-08    Significant
# Gender                      7.696272  5.533501e-03    Significant
# NumberOfDeviceRegistered   63.390385  2.416536e-12    Significant
# PreferedOrderCat          255.910332  3.469095e-54    Significant
# SatisfactionScore          57.614465  9.193893e-12    Significant
# MaritalStatus             166.478192  7.074894e-37    Significant
# Complain                  302.781476  8.161887e-68    Significant

# %% [markdown]
# Overview:
# - Mayoritas kolom dataset memiliki perbedaan signifikan antara pelanggan Churn/Tidak Churn. Artinya, pelanggan dari masing-masing status memiliki perbedaan karakteristik yang signifikan pada kolom tersebut.
# - Hanya saja, terdapat kolom yang tidak memiliki hubungan yang signifikan yaitu `HourSpendOnApp`, `OrderAmountHikeFromlastYear`, `NumberOfAddress`, `CouponUsed` terhadap churn. Ini artinya, baik pelanggan Churn & Tidak Churn memiliki karakteristik yang sama pada kolom tersebut.

# %% [markdown]
# ### ***E.2 Characteristics of Churn Customer segment***

# %% [markdown]
# Setelah mengetahui kolom yang mampu membedakan karakteristik antara pelanggan Churn dan Tidak Churn. Selanjutnya di bagian ini kita akan mendeskripsikan bagaimana karakteristik pelanggan churn secara mendetil di tiap kolom.
#
# Selain mendeskripsikan karakteristik, hasil analisa di bagian ini juga bermanfaat dalam proses pemilihan kolom yang akan dijadikan fitur saat pembuatan model.

# %%
# Drop kolom yang tidak signifikan
df_modelling = df_modelling.drop(['HourSpendOnApp', 'NumberOfAddress', 'OrderAmountHikeFromlastYear', 'CouponUsed'], axis=1)
X_train = X_train.drop(['HourSpendOnApp', 'NumberOfAddress', 'OrderAmountHikeFromlastYear', 'CouponUsed'], axis=1)
X_val = X_val.drop(['HourSpendOnApp', 'NumberOfAddress', 'OrderAmountHikeFromlastYear', 'CouponUsed'], axis=1)
X_test = X_test.drop(['HourSpendOnApp', 'NumberOfAddress', 'OrderAmountHikeFromlastYear', 'CouponUsed'], axis=1)

df_modelling.columns
# Out:
# Index(['Tenure', 'PreferredLoginDevice', 'CityTier', 'WarehouseToHome',
#        'PreferredPaymentMode', 'Gender', 'NumberOfDeviceRegistered',
#        'PreferedOrderCat', 'SatisfactionScore', 'MaritalStatus', 'Complain',
#        'OrderCount', 'DaySinceLastOrder', 'CashbackAmount', 'Churn', 'group'],
#       dtype='object')

# %% [markdown]
# Grafik pelanggan churn di tiap kolom
# - Data dibagi antara train dan validation agar melihat konsistensi data untuk keperluan penentuan pemilihan fitur modelling

# %%
category = ['PreferredLoginDevice', 'CityTier', 'PreferredPaymentMode', 'Gender','NumberOfDeviceRegistered',
            'PreferedOrderCat', 'SatisfactionScore', 'MaritalStatus', 'Complain']
numeric = ['Tenure', 'WarehouseToHome', 'OrderCount', 'DaySinceLastOrder', 'CashbackAmount']
columns = ['PreferredLoginDevice', 'CityTier', 'PreferredPaymentMode', 'Gender','NumberOfDeviceRegistered',
           'PreferedOrderCat', 'SatisfactionScore', 'MaritalStatus', 'Complain',
           'Tenure', 'WarehouseToHome', 'OrderCount', 'DaySinceLastOrder',
           'CashbackAmount']

plt.figure(figsize=(12, 15))

for i, col in enumerate(columns, start=1):
    plt.subplot(5, 3, i)
    if col in numeric:
        df_modelling['bin'] = pd.cut(df_modelling[col], 4)   
        df1 = df_modelling.groupby(['group', 'bin'])['Churn'].mean().reset_index()

        sns.barplot(x='bin', y='Churn', data=df1, hue='group')
        plt.title(f'Feature: {col}')
        plt.xlabel('')
        plt.xticks(rotation=45)
        plt.legend(loc='upper left', bbox_to_anchor=(0.1, 0.94), bbox_transform=plt.gcf().transFigure)
        plt.tight_layout()
        
    elif col in category:
        df1 = df_modelling.groupby(['group',col])['Churn'].mean().reset_index() 
        df1 = df1.sort_values(by='Churn', ascending=True) 
        sns.barplot(x=col, y='Churn', data=df1, hue='group')
        plt.xticks(rotation=45)
        plt.xlabel('')
        plt.legend(loc='upper left', bbox_to_anchor=(0.1, 0.94), bbox_transform=plt.gcf().transFigure)
        plt.title(f'Feature: {col}')  

plt.suptitle('Train-Val Comparison to Data Distribution', x=0.5, y=0.93, fontsize=18)
plt.subplots_adjust(wspace=0.6, hspace=0.9)
plt.show()

# %% [markdown]
# Berdasarkan visualiasi pada tiap kolom dataset yang signifikan, terlihat pola distribusi data untuk menggambarkan karakteristik pelanggan Churn. Kita akan jelaskan satu persatu di akhir bagian ini. Sebelum itu, kita akan melakukan perbaikan pada sejumlah kolom dengan label yang memiliki distribusi serupa. Kita akan menggabungkan label-label yang memiliki jumlah setara seperti `debit card` dan `e-wallet` pada kolom `preferredPaymentMode`

# %% [markdown]
# 3 kolom yang memiliki data dimana persentase churnnya hampir sama, data tersebut digabungkan

# %%
df_modelling['PreferredPaymentMode'] = df_modelling['PreferredPaymentMode'].replace(['Debit Card', 'E wallet'], 'Debit-C & eWallet')
X_train['PreferredPaymentMode'] = X_train['PreferredPaymentMode'].replace(['Debit Card', 'E wallet'], 'Debit-C & eWallet')
X_val['PreferredPaymentMode'] = X_val['PreferredPaymentMode'].replace(['Debit Card', 'E wallet'], 'Debit-C & eWallet')
X_test['PreferredPaymentMode'] = X_test['PreferredPaymentMode'].replace(['Debit Card', 'E wallet'], 'Debit-C & eWallet')

df_modelling['PreferredPaymentMode'] = df_modelling['PreferredPaymentMode'].replace(['Credit Card', 'UPI'], 'Credit-C & UPI')
X_train['PreferredPaymentMode'] = X_train['PreferredPaymentMode'].replace(['Credit Card', 'UPI'], 'Credit-C & UPI')
X_val['PreferredPaymentMode'] = X_val['PreferredPaymentMode'].replace(['Credit Card', 'UPI'], 'Credit-C & UPI')
X_test['PreferredPaymentMode'] = X_test['PreferredPaymentMode'].replace(['Credit Card', 'UPI'], 'Credit-C & UPI')

df_modelling['SatisfactionScore'] = df_modelling['SatisfactionScore'].replace(['Satisfied', 'Very_Satisfied'], 'Satisfied & more_than')
X_train['SatisfactionScore'] = X_train['SatisfactionScore'].replace(['Satisfied', 'Very_Satisfied'], 'Satisfied & more_than')
X_val['SatisfactionScore'] = X_val['SatisfactionScore'].replace(['Satisfied', 'Very_Satisfied'], 'Satisfied & more_than')
X_test['SatisfactionScore'] = X_test['SatisfactionScore'].replace(['Satisfied', 'Very_Satisfied'], 'Satisfied & more_than')

df_modelling['NumberOfDeviceRegistered'] = df_modelling['NumberOfDeviceRegistered'].replace(['1_Device', '2_Devices'], '1-2_Devices')
X_train['NumberOfDeviceRegistered'] = X_train['NumberOfDeviceRegistered'].replace(['1_Device', '2_Devices'], '1-2_Devices')
X_val['NumberOfDeviceRegistered'] = X_val['NumberOfDeviceRegistered'].replace(['1_Device', '2_Devices'], '1-2_Devices')
X_test['NumberOfDeviceRegistered'] = X_test['NumberOfDeviceRegistered'].replace(['1_Device', '2_Devices'], '1-2_Devices')
                                                                                 
df_modelling['NumberOfDeviceRegistered'] = df_modelling['NumberOfDeviceRegistered'].replace(['3_Devices', '4_Devices'], '3-4_Devices')
X_train['NumberOfDeviceRegistered'] = X_train['NumberOfDeviceRegistered'].replace(['3_Devices', '4_Devices'], '3-4_Devices')
X_val['NumberOfDeviceRegistered'] = X_val['NumberOfDeviceRegistered'].replace(['3_Devices', '4_Devices'], '3-4_Devices')
X_test['NumberOfDeviceRegistered'] = X_test['NumberOfDeviceRegistered'].replace(['3_Devices', '4_Devices'], '3-4_Devices')
                                                                                 
df_modelling['PreferedOrderCat'] = df_modelling['PreferedOrderCat'].replace(['Others', 'Laptop & Acc'], 'Laptop, ACC & Others')
X_train['PreferedOrderCat'] = X_train['PreferedOrderCat'].replace(['Others', 'Laptop & Acc'], 'Laptop, ACC & Others')
X_val['PreferedOrderCat'] = X_val['PreferedOrderCat'].replace(['Others', 'Laptop & Acc'], 'Laptop, ACC & Others')
X_test['PreferedOrderCat'] = X_test['PreferedOrderCat'].replace(['Others', 'Laptop & Acc'], 'Laptop, ACC & Others')

# %%
df_modelling['NumberOfDeviceRegistered'].value_counts().sort_index()
# Out:
# NumberOfDeviceRegistered
# 1-2_Devices     425
# 3-4_Devices    3469
# 5_Devices       744
# 6_Devices       136
# Name: count, dtype: int64

# %%
df['NumberOfDeviceRegistered'].value_counts().sort_index()
# Out:
# NumberOfDeviceRegistered
# 1_Device      234
# 2_Devices     275
# 3_Devices    1694
# 4_Devices    2371
# 5_Devices     881
# 6_Devices     162
# Name: count, dtype: int64

# %%
df_churn_counts = df_modelling.groupby('NumberOfDeviceRegistered')['Churn'].sum().reset_index()
df_churn_counts.rename(columns={'Churn': 'ChurnCount'},inplace=True)

# %%
df_total_counts = df_modelling.groupby('NumberOfDeviceRegistered').size().to_frame(name='TotalCount').reset_index()
df_total_counts
# Out:
#   NumberOfDeviceRegistered  TotalCount
# 0              1-2_Devices         425
# 1              3-4_Devices        3469
# 2                5_Devices         744
# 3                6_Devices         136

# %%
df_merged = pd.merge(df_churn_counts, df_total_counts, on='NumberOfDeviceRegistered', how='outer')
df_merged
# Out:
#   NumberOfDeviceRegistered  ChurnCount  TotalCount
# 0              1-2_Devices          39         425
# 1              3-4_Devices         558        3469
# 2                5_Devices         159         744
# 3                6_Devices          47         136

# %%
import pandas as pd

# Assuming df_modelling is your original DataFrame

# Calculate churn counts
df_churn_counts = df_modelling.groupby('NumberOfDeviceRegistered')['Churn'].sum().reset_index()
df_churn_counts.rename(columns={'Churn': 'ChurnCount'}, inplace=True)

# Calculate total counts
df_total_counts = df_modelling.groupby('NumberOfDeviceRegistered').size().to_frame(name='TotalCount').reset_index()
df_total_counts.rename(columns={'CustomerID': 'TotalCount'}, inplace=True)

# Merge DataFrames
df_merged = pd.merge(df_churn_counts, df_total_counts, on='NumberOfDeviceRegistered', how='outer')

# Calculate churn percentage
df_merged['ChurnPercentage'] = (df_merged['ChurnCount'] / df_merged['TotalCount']) * 100

# Sort churn percentage
df_merged = df_merged.sort_values(by='ChurnPercentage')

# Print the churn percentage for each number of devices registered
print(df_merged)
# Out:
#   NumberOfDeviceRegistered  ChurnCount  TotalCount  ChurnPercentage
# 0              1-2_Devices          39         425         9.176471
# 1              3-4_Devices         558        3469        16.085327
# 2                5_Devices         159         744        21.370968
# 3                6_Devices          47         136        34.558824

# %%
import pandas as pd

# Assuming df_modelling is your original DataFrame

# Calculate churn counts
df_churn_counts = df_modelling.groupby('PreferedOrderCat')['Churn'].sum().reset_index()
df_churn_counts.rename(columns={'Churn': 'ChurnCount'}, inplace=True)

# Calculate total counts
df_total_counts = df_modelling.groupby('PreferedOrderCat').size().to_frame(name='TotalCount').reset_index()
df_total_counts.rename(columns={'CustomerID': 'TotalCount'}, inplace=True)

# Merge DataFrames
df_merged = pd.merge(df_churn_counts, df_total_counts, on='PreferedOrderCat', how='outer')

# Calculate churn percentage
df_merged['ChurnPercentage'] = (df_merged['ChurnCount'] / df_merged['TotalCount']) * 100

# Sort churn percentage
df_merged = df_merged.sort_values(by='ChurnPercentage')

# Print the churn percentage for each number of devices registered
print(df_merged)
# Out:
#        PreferedOrderCat  ChurnCount  TotalCount  ChurnPercentage
# 1               Grocery          19         356         5.337079
# 2  Laptop, ACC & Others         190        1965         9.669211
# 0               Fashion         108         700        15.428571
# 3          Mobile Phone         486        1753        27.723902

# %%
category = ['PreferredLoginDevice', 'CityTier', 'PreferredPaymentMode', 'Gender','NumberOfDeviceRegistered',
            'PreferedOrderCat', 'SatisfactionScore', 'MaritalStatus', 'Complain']
numeric = ['Tenure', 'WarehouseToHome', 'OrderCount', 'DaySinceLastOrder', 'CashbackAmount']
columns = ['PreferredLoginDevice', 'CityTier', 'PreferredPaymentMode', 'Gender','NumberOfDeviceRegistered',
           'PreferedOrderCat', 'SatisfactionScore', 'MaritalStatus', 'Complain',
           'Tenure', 'WarehouseToHome', 'OrderCount', 'DaySinceLastOrder',
           'CashbackAmount']

plt.figure(figsize=(12, 15))

for i, col in enumerate(columns, start=1):
    plt.subplot(5, 3, i)
    if col in numeric:
        df_modelling['bin'] = pd.cut(df_modelling[col], 4)   
        df1 = df_modelling.groupby(['group', 'bin'])['Churn'].mean().reset_index()

        sns.barplot(x='bin', y='Churn', data=df1, hue='group')
        plt.title(f'Feature: {col}')
        plt.xlabel('')
        plt.xticks(rotation=45)
        plt.legend(loc='upper left', bbox_to_anchor=(0.1, 0.94), bbox_transform=plt.gcf().transFigure)
        plt.tight_layout()
        
    elif col in category:
        df1 = df_modelling.groupby(['group',col])['Churn'].mean().reset_index() 
        df1 = df1.sort_values(by='Churn', ascending=True) 
        sns.barplot(x=col, y='Churn', data=df1, hue='group')
        plt.xticks(rotation=45)
        plt.xlabel('')
        plt.legend(loc='upper left', bbox_to_anchor=(0.1, 0.94), bbox_transform=plt.gcf().transFigure)
        plt.title(f'Feature: {col}')  

plt.suptitle('Train-Val Comparison to Data Distribution', x=0.5, y=0.93, fontsize=18)
plt.subplots_adjust(wspace=0.6, hspace=0.9)
plt.show()

# %% [markdown]
# Setelah melalukan label ulang pada sejumlah kolom, hasil visualisasi grafik karakteristik pelanggan churn dapat terlihat secara lebih jelas.

# %% [markdown]
# Overviews:
#
# Berdasarkan hasil analisa dapat disimpulkan bahwa pelanggan churn memiliki karakteristik sebagai berikut:
# - Menggunakan `Computer` sebagai akses login ke e-commerece
# - Datang dari masyarakat di kota `tier 3`
# - Banyak menggunakan metode pembayaran `COD`
# - Cenderung berjenis kelamin `male`
# - Mendaftarkan banyak device ke akun e-commerce (4 - 6 device)
# - Berbelanja produk `Mobile phone`
# - Memberikan skor kepuasan pelanggan rendah / `dissatisfied - highly dissatisfied`
# - Belum berkeluarga / single
# - Cenderung pernah memberikan `Complaint` ke e-commerce
# - Datang dari pelanggan yang baru saja bergabung di ecommerce (Memiliki `Tenure` rendah)
# - Berlokasi jauh dari warehouse e-commerece (rata-rata 28 - 36 KM)
# - Memiliki jumlah pesanan ke ecommrce yang rendah (0 - 4.75x)
# - Cenderung baru saja berbelanja di platform (0 - 4.5 hari lalu)
# - Mendapat jumlah cashback yang rendah (109 - 163 dollar)

# %% [markdown]
# Setelah mendapatkan karakteristik umum pelanggan Churn, langkah selanjutnya adalah memilih fitur mana saja yang akan diikutsertakan dalam proses pembuatan model. Proses pemilihan fitur dengan cara memperhatikan pola distribusi di tiap kolom. Fitur dengan pola konsisten dan memiliki nilai separasi yang tinggi untuk kelompok pelanggan churn adalah dua faktor yang jadi kunci pemilihan fitur.
#
# Berdasarkan hasil analisa, ada sejumlah fitur yang tidak memenuhi dua faktor tersebut yaitu: `Gender`, `OrderCount`, `WarehouseToHome`. Ketiga fitur ini akan di drop dalam dataset pembuatan model.

# %%
feature_selected = ['PreferredLoginDevice', 'CityTier', 'PreferredPaymentMode', 'NumberOfDeviceRegistered',
                    'PreferedOrderCat', 'SatisfactionScore', 'MaritalStatus', 'Complain', 'Tenure', 'DaySinceLastOrder',
                    'CashbackAmount']

df_modelling = df_modelling[feature_selected]
X_train = X_train[feature_selected]
X_val = X_val[feature_selected]
X_test = X_test[feature_selected]

# %% [markdown]
# ## F. DATA MODELLING

# %% [markdown]
# ### **F.1 Transform data (Encoding & Scalling)**

# %%
ordinal_mapping = [
    {"col": "CityTier", "mapping": {"Tier_1": 1, "Tier_2": 2, "Tier_3": 3}},
    {"col": "NumberOfDeviceRegistered", "mapping": {"1-2_Devices": 1, "3-4_Devices": 2, "5_Devices": 3, "6_Devices": 4}},
    {"col": "SatisfactionScore", "mapping": {"Satisfied & more_than": 1, "Neutral": 2, "Dissatisfied": 3, "Highly_Dissatisfied": 4}},
    {"col": "PreferedOrderCat", "mapping": {"Grocery": 1, "Fashion": 2, "Mobile Phone": 3, "Laptop, ACC & Others": 4}}]

transformer = ColumnTransformer([
    ('One Hot Encoding', OneHotEncoder(drop='first'), ['PreferredLoginDevice', 'PreferredPaymentMode',
                                                       'MaritalStatus', 'Complain']),
    ('Ordinal Encoding', ce.OrdinalEncoder(cols=['CityTier', 'NumberOfDeviceRegistered', 'SatisfactionScore', 'PreferedOrderCat'], mapping=ordinal_mapping), ['CityTier', 'NumberOfDeviceRegistered', 'SatisfactionScore', 'PreferedOrderCat']),
    ('Robust', RobustScaler(), ['Tenure', 'DaySinceLastOrder', 'CashbackAmount']),
])

# %%
transformer.fit(X_train)
# Out:
# ColumnTransformer(transformers=[('One Hot Encoding',
#                                  OneHotEncoder(drop='first'),
#                                  ['PreferredLoginDevice',
#                                   'PreferredPaymentMode', 'MaritalStatus',
#                                   'Complain']),
#                                 ('Ordinal Encoding',
#                                  OrdinalEncoder(cols=['CityTier',
#                                                       'NumberOfDeviceRegistered',
#                                                       'SatisfactionScore',
#                                                       'PreferedOrderCat'],
#                                                 mapping=[{'col': 'CityTier',
#                                                           'data_type': dtype('O'),
#                                                           'mapping': Tier_1    1
# Tier_2    2
# Tier...
# ...

# %%
validating = pd.DataFrame(transformer.fit_transform(X_train), columns=transformer.get_feature_names_out())
validating.columns
# Out:
# Index(['One Hot Encoding__PreferredLoginDevice_Mobile Phone',
#        'One Hot Encoding__PreferredPaymentMode_Credit-C & UPI',
#        'One Hot Encoding__PreferredPaymentMode_Debit-C & eWallet',
#        'One Hot Encoding__MaritalStatus_Married',
#        'One Hot Encoding__MaritalStatus_Single',
#        'One Hot Encoding__Complain_non-Complain', 'Ordinal Encoding__CityTier',
#        'Ordinal Encoding__NumberOfDeviceRegistered',
#        'Ordinal Encoding__SatisfactionScore',
#        'Ordinal Encoding__PreferedOrderCat', 'Robust__Tenure',
#        'Robust__DaySinceLastOrder', 'Robust__CashbackAmount'],
#       dtype='object')

# %%
X_train['SatisfactionScore'].value_counts()
# Out:
# SatisfactionScore
# Satisfied & more_than    1233
# Neutral                  1187
# Highly_Dissatisfied       777
# Dissatisfied              736
# Name: count, dtype: int64

# %%
validating['Ordinal Encoding__SatisfactionScore'].value_counts()
# Out:
# Ordinal Encoding__SatisfactionScore
# 1.0    1233
# 2.0    1187
# 4.0     777
# 3.0     736
# Name: count, dtype: int64

# %%
X_train['SatisfactionScore'].head(10)
# Out:
# 1418             Dissatisfied
# 2410                  Neutral
# 3853             Dissatisfied
# 3512                  Neutral
# 2129                  Neutral
# 3136    Satisfied & more_than
# 799                   Neutral
# 3529      Highly_Dissatisfied
# 1651                  Neutral
# 534     Satisfied & more_than
# Name: SatisfactionScore, dtype: object

# %%
X_train['PreferedOrderCat'].value_counts()
# Out:
# PreferedOrderCat
# Laptop, ACC & Others    1630
# Mobile Phone            1437
# Fashion                  576
# Grocery                  290
# Name: count, dtype: int64

# %%
validating['Ordinal Encoding__PreferedOrderCat'].value_counts()
# Out:
# Ordinal Encoding__PreferedOrderCat
# 4.0    1630
# 3.0    1437
# 2.0     576
# 1.0     290
# Name: count, dtype: int64

# %%
validating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3933 entries, 0 to 3932
# Data columns (total 13 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   One Hot Encoding__PreferredLoginDevice_Mobile Phone       3933 non-null   float64
#  1   One Hot Encoding__PreferredPaymentMode_Credit-C & UPI     3933 non-null   float64
#  2   One Hot Encoding__PreferredPaymentMode_Debit-C & eWallet  3933 non-null   float64
#  3   One Hot Encoding__MaritalStatus_Married                   3933 non-null   float64
#  4   One Hot Encoding__MaritalStatus_Single                    3933 non-null   float64
#  5   One Hot Encoding__Complain_non-Complain                   3933 non-null   float64
#  6   Ordinal Encoding__CityTier                                3933 non-null   float64
#  7   Ordinal Encoding__NumberOfDeviceRegistered                3933 non-null   float64
# ...

# %%
knn = KNeighborsClassifier()
tree = DecisionTreeClassifier(random_state=2020) 
rf = RandomForestClassifier(random_state=2020) 
ada = AdaBoostClassifier(tree, random_state=2020)
gbc = GradientBoostingClassifier(random_state=2020)
xgb = XGBClassifier(random_state=2020)
lgbm = LGBMClassifier(random_state=2020)

# %%
models = [ knn, tree, rf, ada, gbc, xgb, lgbm]
model_names = ['KNN', 'Decision Tree', 'Random Forest', 'AdaBoost', 'GBoost', 'XGBoost', 'LightGBM']
score = []
mean = []
std = []

for model in models:
    skfold = StratifiedKFold(n_splits=5)
    estimator_default = Pipeline([
        ('preprocess', transformer),
        ('model', model)
    ])
    model_cv = cross_val_score(estimator_default, X_train, y_train, cv=skfold, scoring='f1')
    score.append(model_cv)
    mean.append(model_cv.mean())
    std.append(model_cv.std())

results_df = pd.DataFrame({
    'model': model_names,
    'mean f1': mean,
    'StdDev': std
}).set_index('model').sort_values(by='mean f1', ascending=False)

results_df.round(3)
# Out:
# [LightGBM] [Info] Number of positive: 530, number of negative: 2616
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000204 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 337
# [LightGBM] [Info] Number of data points in the train set: 3146, number of used features: 13
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.168468 -> initscore=-1.596525
# [LightGBM] [Info] Start training from score -1.596525
# [LightGBM] [Info] Number of positive: 529, number of negative: 2617
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000201 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 337
# [LightGBM] [Info] Number of data points in the train set: 3146, number of used features: 13
# ...

# %% [markdown]
# ### Oversample

# %%
# Import oversampling method
Smote = SMOTE(random_state = 2020)
Ros = RandomOverSampler(random_state=2020)

# %%
Oversampler_Selection = [Smote, Ros, None]
model_names = ['XGB_smote', 'XGB_ros', 'XGB']

score = []
mean = []
std = []

for i in Oversampler_Selection:
    skfold=StratifiedKFold(n_splits=5)
    estimator_tuning =Pipeline([
        ('preprocess',transformer),
        ('resampler',i),
        ('model',xgb)])
    model_cv = cross_val_score(estimator_tuning, X_train, y_train, cv=skfold, scoring='f1')
    score.append(model_cv)
    mean.append(model_cv.mean())
    std.append(model_cv.std())
        
results_df = pd.DataFrame({
    'model': model_names,
    'mean f1 Score': mean,
    'StdDev': std
}).set_index('model').sort_values(by='mean f1 Score', ascending=False)

results_df.round(3)
# Out:
#            mean f1 Score  StdDev
# model
# XGB_ros            0.818   0.035
# XGB                0.817   0.021
# XGB_smote          0.814   0.032

# %%
Oversampler_Selection = [Smote, Ros, None]
model_names = ['TREE_smote', 'TREE_ros', 'TREE']

score = []
mean = []
std = []

for i in Oversampler_Selection:
    skfold=StratifiedKFold(n_splits=5)
    estimator_tuning =Pipeline([
        ('preprocess',transformer),
        ('resampler',i),
        ('model',tree)])
    model_cv = cross_val_score(estimator_tuning, X_train, y_train, cv=skfold, scoring='f1')
    score.append(model_cv)
    mean.append(model_cv.mean())
    std.append(model_cv.std())
        
results_df = pd.DataFrame({
    'model': model_names,
    'mean f1 Score': mean,
    'StdDev': std
}).set_index('model').sort_values(by='mean f1 Score', ascending=False)

results_df.round(3)
# Out:
#             mean f1 Score  StdDev
# model
# TREE                0.766   0.029
# TREE_ros            0.762   0.027
# TREE_smote          0.750   0.010

# %%
Oversampler_Selection = [Smote, Ros, None]
model_names = ['ADA_smote', 'ADA_ros', 'ADABoost']

score = []
mean = []
std = []

for i in Oversampler_Selection:
    skfold=StratifiedKFold(n_splits=5)
    estimator_tuning =Pipeline([
        ('preprocess',transformer),
        ('resampler',i),
        ('model',ada)])
    model_cv = cross_val_score(estimator_tuning, X_train, y_train, cv=skfold, scoring='f1')
    score.append(model_cv)
    mean.append(model_cv.mean())
    std.append(model_cv.std())
        
results_df = pd.DataFrame({
    'model': model_names,
    'mean f1 Score': mean,
    'StdDev': std
}).set_index('model').sort_values(by='mean f1 Score', ascending=False)

results_df.round(3)
# Out:
#            mean f1 Score  StdDev
# model
# ADA_ros            0.767   0.025
# ADABoost           0.760   0.020
# ADA_smote          0.745   0.016

# %% [markdown]
# ### feature selection

# %%
feature_selection_XGB = RFE(estimator=XGBClassifier(random_state=2020), n_features_to_select=11)

feature_selection = [feature_selection_XGB, None]
model_names = ['XGB_ROS_FS', 'XGB_ROS']

score = []
mean = []
std = []

for i in feature_selection:
    skfold = StratifiedKFold(n_splits=5)
    estimator_tuning = Pipeline([
        ('preprocess', transformer),
        ('resampler', Ros),
        ('feature_selector', i),
        ('model', xgb)
    ])
    model_cv = cross_val_score(estimator_tuning, X_train, y_train, cv=skfold, scoring='f1')
    score.append(model_cv)
    mean.append(model_cv.mean())
    std.append(model_cv.std())

results_df = pd.DataFrame({
    'model': model_names,
    'mean f1 Score': mean,
    'StdDev': std
}).set_index('model').sort_values(by='mean f1 Score', ascending=False)

results_df.round(3)
# Out:
#             mean f1 Score  StdDev
# model
# XGB_ROS             0.818   0.035
# XGB_ROS_FS          0.805   0.024

# %%
feature_selection_TREE = RFE(estimator=DecisionTreeClassifier(random_state=2020), n_features_to_select=8)

feature_selection = [feature_selection_TREE, None]
model_names = ['TREE_SMOTE_FS', 'TREE_SMOTE']


score = []
mean = []
std = []

for i in feature_selection:
    skfold = StratifiedKFold(n_splits=5)
    estimator_tuning = Pipeline([
        ('preprocess', transformer),
        ('resampler', Ros),
        ('feature_selector', i),
        ('model', tree)
    ])
    model_cv = cross_val_score(estimator_tuning, X_train, y_train, cv=skfold, scoring='f1')
    score.append(model_cv)
    mean.append(model_cv.mean())
    std.append(model_cv.std())

results_df = pd.DataFrame({
    'model': model_names,
    'mean f1 Score': mean,
    'StdDev': std
}).set_index('model').sort_values(by='mean f1 Score', ascending=False)

results_df.round(3)
# Out:
#                mean f1 Score  StdDev
# model
# TREE_SMOTE_FS          0.781   0.020
# TREE_SMOTE             0.762   0.027

# %%
feature_selection_ADA = RFE(estimator=AdaBoostClassifier(random_state=2020), n_features_to_select=11)

feature_selection = [feature_selection_ADA, None]
model_names = ['ADA_FS', 'model']

score = []
mean = []
std = []

for i in feature_selection:
    skfold = StratifiedKFold(n_splits=5)
    estimator_tuning = Pipeline([
        ('preprocess', transformer),
        ('feature_selector', i),
        ('model', ada)
    ])
    model_cv = cross_val_score(estimator_tuning, X_train, y_train, cv=skfold, scoring='f1')
    score.append(model_cv)
    mean.append(model_cv.mean())
    std.append(model_cv.std())

results_df = pd.DataFrame({
    'model': model_names,
    'mean f1 Score': mean,
    'StdDev': std
}).set_index('model').sort_values(by='mean f1 Score', ascending=False)

results_df.round(3)
# Out:
#         mean f1 Score  StdDev
# model
# ADA_FS          0.771   0.024
# model           0.760   0.020

# %% [markdown]
# Berdasarkan model selection, terpilih model Gradient Boosting. Gradient Boosting adalah sebuah teknik ensemble yang menggabungkan beberapa model yang lemah (weak model) menjadi sebuah model yang kuat. Model-model lemah ini sering disebut dengan weak learners, dan dapat berupa model regresi atau klasifikasi sederhana seperti Decision Tree. Algoritma ini menggunakan pendekatan iteratif, di mana setiap iterasi bertujuan untuk meningkatkan model sebelumnya dengan menambahkan model baru. Proses ini dilakukan secara berulang-ulang hingga model yang dihasilkan memenuhi kriteria tertentu, seperti nilai loss function yang cukup kecil.
#
# Proses iteratif dalam algoritma Gradient Boosting terdiri dari beberapa tahap, yaitu:
#
# Inisialisasi model Membuat weak model Menghitung residual error Menyusun kembali data training Membuat model baru Menggabungkan model Iterasi berulang Gradient Boosting ini sangat cocok diterapkan pada analisis Churn. Gradient Boosting dapat menangani hubungan non-linier antara fitur dan variabel target. Hal ini dapat berguna saat mencari pola kompleks yang mungkin terkait dengan perilaku pelanggan yang berpotensi berhenti. Selanjutnya, jika data pelanggan terstruktur dengan baik, Gradient Boosting dapat memberikan hasil yang akurat. Ini termasuk variabel-variabel seperti frekuensi penggunaan, lamanya penggunaan, dan fitur-fitur lainnya yang dapat diambil dari data pelanggan. Terakhir, Gradient Boosting dapat menangani baik variabel target kategorikal maupun kontinu. Ini berguna jika variabel target churn bersifat biner (misalnya, churn atau tidak churn). Selain itu, outliers dan missing values juga telah ditangani dengan baik, sehingga dapat lebih mendukung kinerja model Gradient Boosting ini.

# %% [markdown]
# ### Hyper Parameter Tuning: XGB

# %%
xgb = XGBClassifier(random_state=2020)
xgb.get_params()
# Out:
# {'objective': 'binary:logistic',
#  'base_score': None,
#  'booster': None,
#  'callbacks': None,
#  'colsample_bylevel': None,
#  'colsample_bynode': None,
#  'colsample_bytree': None,
#  'device': None,
#  'early_stopping_rounds': None,
#  'enable_categorical': False,
#  'eval_metric': None,
#  'feature_types': None,
#  'gamma': None,
#  'grow_policy': None,
#  'importance_type': None,
#  'interaction_constraints': None,
#  'learning_rate': None,
#  'max_bin': None,
#  'max_cat_threshold': None,
#  'max_cat_to_onehot': None,
#  'max_delta_step': None,
#  'max_depth': None,
#  'max_leaves': None,
#  'min_child_weight': None,
#  'missing': nan,
#  'monotone_constraints': None,
#  'multi_strategy': None,
#  'n_estimators': None,
#  'n_jobs': None,
#  'num_parallel_tree': None,
#  'random_state': 2020,
#  'reg_alpha': None,
#  'reg_lambda': None,
#  'sampling_method': None,
#  'scale_pos_weight': None,
#  'subsample': None,
#  'tree_method': None,
#  'validate_parameters': None,
# ...

# %%
# Hyperparameter Tuning pada XGB dengan Random Over Sampling dan Feature Selection
xgb = XGBClassifier(random_state=2020)

estimator = Pipeline([
    ('preprocess', transformer),
    ('resampler',Ros),
    ('feature_selector', feature_selection_XGB),
    ('model', xgb)])

hyperparam_space = {    
    'model__n_estimators': [100, 200, 300],
    'model__max_depth': [3, 5, 7],
    'model__learning_rate': [0.01, 0.1, 0.3],
    'model__subsample': [0.7, 0.8, 0.9],
}

grid_search_xgb = GridSearchCV(
    estimator, 
    param_grid = hyperparam_space, 
    cv = skfold,
    scoring = 'f1',
    n_jobs = -1 
)

# %%
grid_search_xgb.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=False),
#              estimator=Pipeline(steps=[('preprocess',
#                                         ColumnTransformer(transformers=[('One '
#                                                                          'Hot '
#                                                                          'Encoding',
#                                                                          OneHotEncoder(drop='first'),
#                                                                          ['PreferredLoginDevice',
#                                                                           'PreferredPaymentMode',
#                                                                           'MaritalStatus',
#                                                                           'Complain']),
#                                                                         ('Ordinal '
# ...

# %%
print('best score',grid_search_xgb.best_score_)
print('best param',grid_search_xgb.best_params_)
# Out:
# best score 0.8223722451158626
# best param {'model__learning_rate': 0.3, 'model__max_depth': 7, 'model__n_estimators': 100, 'model__subsample': 0.7}

# %%
gs_result = pd.DataFrame(grid_search_xgb.cv_results_)
gs_result[gs_result['rank_test_score']<4]
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 53       1.092504      0.052722         0.031407        0.001127
# 72       0.713895      0.028966         0.025735        0.000713
# 75       0.900998      0.035477         0.031594        0.004183
#
#    param_model__learning_rate param_model__max_depth  \
# 53                        0.1                      7
# 72                        0.3                      7
# 75                        0.3                      7
#
#    param_model__n_estimators param_model__subsample  \
# 53                       300                    0.9
# 72                       100                    0.7
# 75                       200                    0.7
#
#                                                                                                        params  \
# 53  {'model__learning_rate': 0.1, 'model__max_depth': 7, 'model__n_estimators': 300, 'model__subsample': 0.9}
# ...

# %%
# Hyperparameter Tuning pada XGB dengan Random Over Sampling dan Tanpa Feature Selection

xgb = XGBClassifier(random_state=2020)

estimator2 = Pipeline([
    ('preprocess', transformer),
    ('resampler',Ros),
    ('model', xgb)])

hyperparam_space = {    
    'model__n_estimators': [100, 200, 300],
    'model__max_depth': [3, 5, 7],
    'model__learning_rate': [0.01, 0.1, 0.3],
    'model__subsample': [0.7, 0.8, 0.9],
}

grid_search_xgb2 = GridSearchCV(
    estimator2, 
    param_grid = hyperparam_space, 
    cv = skfold,
    scoring = 'f1',
    n_jobs = -1 
)

# %%
grid_search_xgb2.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=False),
#              estimator=Pipeline(steps=[('preprocess',
#                                         ColumnTransformer(transformers=[('One '
#                                                                          'Hot '
#                                                                          'Encoding',
#                                                                          OneHotEncoder(drop='first'),
#                                                                          ['PreferredLoginDevice',
#                                                                           'PreferredPaymentMode',
#                                                                           'MaritalStatus',
#                                                                           'Complain']),
#                                                                         ('Ordinal '
# ...

# %%
print('best score',grid_search_xgb2.best_score_)
print('best param',grid_search_xgb2.best_params_)
# Out:
# best score 0.8337943098544969
# best param {'model__learning_rate': 0.3, 'model__max_depth': 7, 'model__n_estimators': 100, 'model__subsample': 0.9}

# %%
gs_result2 = pd.DataFrame(grid_search_xgb2.cv_results_)
gs_result2[gs_result2['rank_test_score']<4]
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 74       0.315544      0.009003         0.029380        0.004132
# 77       0.510200      0.005919         0.033387        0.002698
# 80       0.622817      0.037780         0.030185        0.005081
#
#    param_model__learning_rate param_model__max_depth  \
# 74                        0.3                      7
# 77                        0.3                      7
# 80                        0.3                      7
#
#    param_model__n_estimators param_model__subsample  \
# 74                       100                    0.9
# 77                       200                    0.9
# 80                       300                    0.9
#
#                                                                                                        params  \
# 74  {'model__learning_rate': 0.3, 'model__max_depth': 7, 'model__n_estimators': 100, 'model__subsample': 0.9}
# ...

# %% [markdown]
# ### Model Evaluation: XGB

# %%
# XGB dengan Random Over Sampling dan feature selection

xgb_default = XGBClassifier(random_state=2020)

estimator_xgb_default = Pipeline([
    ('preprocess', transformer),   
    ('resampler',Ros), 
    ('feature_selector', feature_selection_XGB),
    ('model', xgb_default)])

estimator_xgb_default.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('One Hot Encoding',
#                                                   OneHotEncoder(drop='first'),
#                                                   ['PreferredLoginDevice',
#                                                    'PreferredPaymentMode',
#                                                    'MaritalStatus',
#                                                    'Complain']),
#                                                  ('Ordinal Encoding',
#                                                   OrdinalEncoder(cols=['CityTier',
#                                                                        'NumberOfDeviceRegistered',
#                                                                        'SatisfactionScore',
#                                                                        'PreferedOrderCat'],
# ...

# %%
# XGB dengan Random Over Sampling dan feature selection

best_model_xgb = grid_search_xgb.best_estimator_
best_model_xgb.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('One Hot Encoding',
#                                                   OneHotEncoder(drop='first'),
#                                                   ['PreferredLoginDevice',
#                                                    'PreferredPaymentMode',
#                                                    'MaritalStatus',
#                                                    'Complain']),
#                                                  ('Ordinal Encoding',
#                                                   OrdinalEncoder(cols=['CityTier',
#                                                                        'NumberOfDeviceRegistered',
#                                                                        'SatisfactionScore',
#                                                                        'PreferedOrderCat'],
# ...

# %%
# XGB dengan Random Over Sampling, tanpa Feature Selection

xgb_default2 = XGBClassifier(random_state=2020)

estimator_xgb_default2= Pipeline([
    ('preprocess', transformer),   
    ('resampler',Ros),
    ('model', xgb_default2)])

estimator_xgb_default2.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('One Hot Encoding',
#                                                   OneHotEncoder(drop='first'),
#                                                   ['PreferredLoginDevice',
#                                                    'PreferredPaymentMode',
#                                                    'MaritalStatus',
#                                                    'Complain']),
#                                                  ('Ordinal Encoding',
#                                                   OrdinalEncoder(cols=['CityTier',
#                                                                        'NumberOfDeviceRegistered',
#                                                                        'SatisfactionScore',
#                                                                        'PreferedOrderCat'],
# ...

# %%
# XGB dengan Random Over Sampling, tanpa Feature Selection

best_model_xgb2 = grid_search_xgb2.best_estimator_
best_model_xgb2.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('One Hot Encoding',
#                                                   OneHotEncoder(drop='first'),
#                                                   ['PreferredLoginDevice',
#                                                    'PreferredPaymentMode',
#                                                    'MaritalStatus',
#                                                    'Complain']),
#                                                  ('Ordinal Encoding',
#                                                   OrdinalEncoder(cols=['CityTier',
#                                                                        'NumberOfDeviceRegistered',
#                                                                        'SatisfactionScore',
#                                                                        'PreferedOrderCat'],
# ...

# %% [markdown]
# ### XGB: Data Test

# %%
#Data Test pada XGB dengan Random Over Sampling dan Feature Selection
y_pred_default_xgb = estimator_xgb_default.predict(X_test)
y_pred_tuned_xgb = best_model_xgb.predict(X_test)

f1_score_default_xgb = f1_score(y_test, y_pred_default_xgb)
f1_score_tuned_xgb = f1_score(y_test, y_pred_tuned_xgb)

print('F1 Score XGB Default dengan  Feature Selection : ', f1_score_default_xgb)
print('F1 Score XGB Tuned dengan  Feature Selection: ', f1_score_tuned_xgb)
# Out:
# F1 Score XGB Default dengan  Feature Selection :  0.888135593220339
# F1 Score XGB Tuned dengan  Feature Selection:  0.9172413793103448

# %%
#Data Test pada XGB dengan Random Over Sampling
y_pred_default_xgb2 = estimator_xgb_default2.predict(X_test)
y_pred_tuned_xgb2 = best_model_xgb2.predict(X_test)

f1_score_default_xgb2 = f1_score(y_test, y_pred_default_xgb2)
f1_score_tuned_xgb2 = f1_score(y_test, y_pred_tuned_xgb2)

print('F1 Score XGB Default  tanpa feature selection: ', f1_score_default_xgb2)
print('F1 Score XGB Tuned  tanpa feature selection: ', f1_score_tuned_xgb2)
# Out:
# F1 Score XGB Default  tanpa feature selection:  0.9128919860627178
# F1 Score XGB Tuned  tanpa feature selection:  0.9187279151943463

# %%
report_default_xgb2 = classification_report(y_test, y_pred_default_xgb2)
report_tuned_xgb2 = classification_report(y_test, y_pred_tuned_xgb2)

print('Classification Report Default XGB : \n', report_default_xgb2)
print('Classification Report Tuned XGB : \n', report_tuned_xgb2)
# Out:
# Classification Report Default XGB :
#                precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       701
#            1       0.90      0.92      0.91       142
#
#     accuracy                           0.97       843
#    macro avg       0.94      0.95      0.95       843
# weighted avg       0.97      0.97      0.97       843
#
# Classification Report Tuned XGB :
#                precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       701
#            1       0.92      0.92      0.92       142
#
#     accuracy                           0.97       843
#    macro avg       0.95      0.95      0.95       843
# weighted avg       0.97      0.97      0.97       843

# %%
def plot_confusion_matrix(y_true, y_pred, model_title, ax):
    sns.heatmap(confusion_matrix(y_true, y_pred), annot=True, fmt='.0f', ax=ax)
    ax.set_xlabel('Predicted Labels')
    ax.set_ylabel('True Labels')
    ax.set_title(f'{model_title} Confusion Matrix', size=10)

# Plotting
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 5))

plot_confusion_matrix(y_test, y_pred_default_xgb2, 'Default XGB Model', axes[0])

plot_confusion_matrix(y_test, y_pred_tuned_xgb2, 'Tuning XGB Model', axes[1])

plt.tight_layout()
plt.show()

# %% [markdown]
# **ROC-AUC**

# %%
def plot_roc_curve(true_y, y_prob):
    """
    plots the roc curve based of the probabilities
    """

    fpr, tpr, thresholds = roc_curve(true_y, y_prob)
    plt.plot(fpr, tpr)
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')

plot_roc_curve(y_test, y_pred_tuned_xgb)
print(f'AUC score: {roc_auc_score(y_test, y_pred_default_xgb2)}')
# Out:
# AUC score: 0.9512818709690382

# %% [markdown]
# ## G. FEATURE IMPORTANCE

# %%
save_model = estimator_xgb_default2.fit(X_train, y_train)
preprocess = save_model.named_steps['preprocess']

# %%
cols = list(save_model['preprocess'].named_transformers_['One Hot Encoding'].get_feature_names_out()) + \
       list(save_model['preprocess'].named_transformers_['Ordinal Encoding'].get_feature_names_out()) + \
       ['Tenure', 'DaySinceLastOrder', 'CashbackAmount']

# Melakukan transformasi pada data menggunakan pra-pemrosesan
selected_features = preprocess.transform(df_modelling)

# Ekstrak model dari pipeline
model = save_model.named_steps['model']

# Menghitung SHAP values
explainer = shap.TreeExplainer(model, data=selected_features, feature_perturbation="interventional", model_output="probability")
shap_values = explainer.shap_values(selected_features)
# Out:
# 100%|===================| 4771/4774 [00:23<00:00]

# %%
# Plot untuk Feature Importance
plt.figure(figsize=(10, 8))
shap.summary_plot(shap_values, selected_features, feature_names=cols, plot_type='bar', show=False)
plt.xlabel('SHAP Value')
plt.ylabel('Features')
plt.title('Feature Importance')
plt.show()

# Plot untuk SHAP Values
plt.figure(figsize=(10, 8))
shap.summary_plot(shap_values, selected_features, feature_names=cols, show=False)
plt.xlabel('SHAP Value')
plt.ylabel('Features')
plt.title('SHAP Feature')
plt.show()

# %% [markdown]
# ## H. CONCLUSION & RECOMMENDATION

# %% [markdown]
# ### Effect of Model to Business

# %% [markdown]
# Hasil pembuatan akhir model:

# %%
print('F1 Score XGB Default: ',f1_score_default_xgb2)
print('Classification Report Default XGB : \n', report_default_xgb2)
# Out:
# F1 Score XGB Default:  0.9128919860627178
# Classification Report Default XGB :
#                precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       701
#            1       0.90      0.92      0.91       142
#
#     accuracy                           0.97       843
#    macro avg       0.94      0.95      0.95       843
# weighted avg       0.97      0.97      0.97       843

# %% [markdown]
# **Performa model dalam memprediksi pelanggan terhadap potensi Churn/Tidak Churn berdasarkan F1 score:**
# Pelanggan Tidak Churn (0): Model memiliki F1-score sebesar 0.98, yang menunjukkan bahwa model sangat baik dalam memprediksi pelanggan yang tidak akan churn dengan presisi dan recall yang sangat tinggi.
#
#
# Pelanggan Churn (1): Model memiliki F1-score sebesar 0.91, yang menunjukkan bahwa model cukup baik dalam memprediksi pelanggan yang berpotensi churn. Model memiliki recall sebesar 0.92, yang berarti model mampu mendeteksi 92% dari total pelanggan yang benar-benar churn.

# %% [markdown]
# Berdasarkan SHAP analysis, terdapat setidaknya 5 faktor utama penentu churn.
# 1. Tenure: Semakin rendah Tenure semakin memungkinkan Churn
# 2. Complain: Customer yang menyampaikan Complain akibat ketidakpuasan dapat berpotensi untuk Churn
# 3. CashbackAmount: Customer yang mendapatkan sedikit Cashback berpotensi untuk Churn
# 4. DaySinceLastOrder: Customer yang belum lama melakukan Order dapat berpotensi Churn
# 5. SatisfactionScore: Semakin tidak puas nilai yang diberikan oleh Customer akan berpotensi untuk Curn juga
#
# Oleh sebab itu, promosi berupa Cashback dapat diberikan kepada pelanggan dengan 5 faktor utama tersebut. Kenapa promosi berupa cashback? Sebab, Cashback merupakan uang kembali yang didapatkan Customer setelah melakukan order pada ecommerce. Cashback baru dapat digunakan ketika customer melakukan pembelian selanjutnya. Dengan demikian, cashback ini dapat menimbulkan efek retensi dari customer terhadap platform ecommerce dan meminimalisir potensi Churn. Selain efek retensi yang diberikan oleh cashback, tim bisnis juga pada akhirnya perlu memperbaiki performa dari segi pelayanan untuk meningkatkan tingkat kepuasan berbelanja customer, menginat Complain dan SatisfactionScore masuk ke dalam 5 faktor utama penentu Churn.

# %% [markdown]
# **Manfaat terhadap bisnis e-commerce**
#
# Mari kita ilustrasikan bagaimana model berdampak kepada bisnis e-commerce menggunakan grafik confusion matrix hasil evaluasi model

# %%
sns.heatmap(confusion_matrix(y_test, y_pred_default_xgb), annot=True, fmt='.0f')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('XGboost Confusion Matrix', size=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Model mampu memprediksi klasifikasi customer yang akan Churn/Tidak churn dengan akurat**
#
# Dari 841 pelanggan yang dijadikan data test pada evaluasi model, model XGBoost yang dibangun mampu mengklasifikasikan sebanyak;
# - 679 pelanggan yang tidak Churn (True Negative)
# - 131 pelanggan Churn (True Positif)
# - Meski masih ada sekitar 33 orang terklasifikasi secara kurang tepat (False Positive & False Negative)

# %% [markdown]
# **Model membantu e-commerce dalam penentuan pemberian promo ke pelanggan Churn secara akurat**.

# %%
budget_perCust = 50000

data_test = pd.concat([X_test, y_test], axis=1)
total_cust_churn = data_test[data_test['Churn']==1]['Churn'].sum()
total_cust_churn
# Out:
# 142

# %%
# Cek logika dari data nilai negatif menggunakan csv
rule_based = data_test[(data_test['Tenure']<7.75) &
                       (data_test['Complain']=='Complain')]

print(f'Metode Pemberian Cashback pada Customer Churn dengan Metode RULE-BASED:\n')
print('Total Pelanggan : 841')
print(f'Rule-Based Churn Cost: Rp{(rule_based.shape[0]*budget_perCust):,} atau sekitar {rule_based.shape[0]} Customer.')
print(f'Jumlah customer yang benar-benar churn dan tercover cashback: {rule_based["Churn"].value_counts()[1]} Customer')
# Out:
# Metode Pemberian Cashback pada Customer Churn dengan Metode RULE-BASED:
#
# Total Pelanggan : 841
# Rule-Based Churn Cost: Rp5,200,000 atau sekitar 104 Customer.
# Jumlah customer yang benar-benar churn dan tercover cashback: 60 Customer

# %% [markdown]
# Biaya promo Cashback = 50.000
#
# Total biaya promo Cashback = 104 X 50.000 = 5.200.000

# %% [markdown]
# Asumsikan pendapatan rata-rata pelanggan pertahun 2juta
#
# maka total pendapatan yang diselamatkan 60 x 2 juta = 120 juta

# %% [markdown]
# ## Dengan Model Machine Learning

# %%
cm = confusion_matrix(y_test, y_pred_default_xgb)
tn, fp, fn, tp = cm.ravel()
print(f'True Negative (TN): {tn}')
print(f'False Positive (FP): {fp}')
print(f'False Negative (FN): {fn}')
print(f'True Positive (TP): {tp}')
# Out:
# True Negative (TN): 679
# False Positive (FP): 22
# False Negative (FN): 11
# True Positive (TP): 131

# %%
print(f'Pelanggan yang diprediksi Churn : {total_cust_churn}')
print(f'Biaya Promo Cashback: {total_cust_churn} * 50.000 = {total_cust_churn * 50000}')
# Out:
# Pelanggan yang diprediksi Churn : 142
# Biaya Promo Cashback: 142 * 50.000 = 7100000

# %%
print(f'Pendapatan yang diselamatkan : {tp} (TP)')
print(f'Total pendapatan yg diselamatkan : {tp} * 2juta = {tp *2000000} ')
# Out:
# Pendapatan yang diselamatkan : 131 (TP)
# Total pendapatan yg diselamatkan : 131 * 2juta = 262000000

# %% [markdown]
# Apabila menggunakan estimasi sederhana, e-commerece hanya dapat mendeteksi pemberian promo ke sebanyak 104 pelanggan. Namun dari pemberian tersebut, akurasi promo diberikan ke pelanggan Churn hanya sebanyak 60 pelanggan. Misal budget percustomer = 50.000, maka biaya yang dikeluarkan untuk pemberian cashback sebesar 5.200.000. Adapun pendapatan yang diselamatkan adalah 120juta (dengan asumsi rata-rata pendapatan perpelanggan 2juta pertahun)
#
#
#
# Dengan adanya Model XGBoost ini, e-commerce dapat mengcover pemberian promo ke lebih banyak pelanggan churn dan juga tepat sasaran.
# - Promo dapat diberikan ke sebanyak 142 pelanggan, dengan akurasi pemberian ke pelanggan yang benar-benar churn adalah 131 orang. Biaya yang dikeluarkan untuk pemberian cashback sebesar 7.100.000. Adapun pendapatan yang diselamatkan adalah 262 juta
#
# Perbandingan
#
# Biaya menggunakan Modelling Approach sekitar 36.5% lebih mahal dari Rule-Based Approach namun mampu menjangkau 2.1 kali customer churn lebih banyak dan mampu menyelamatkan pendapatan perusahaan 1.18 kali lebih besar dalam satu tahun daripada tanpa model.

# %% [markdown]
# ### Model limitation

# %% [markdown]
# 1. Model memprediksi pelanggan Churn terbatas pada fitur-fitur yang digunakan dalam proses pembuatan model, yaitu: ['PreferredLoginDevice',
#  'CityTier',
#  'PreferredPaymentMode',
#  'NumberOfDeviceRegistered',
#  'PreferedOrderCat',
#  'SatisfactionScore',
#  'MaritalStatus',
#  'Complain',
#  'Tenure',
#  'DaySinceLastOrder',
#  'CashbackAmount']
# - Apabila ada fitur baru pada dataset, maka model belum bisa menghitung pengaruhnya kepada prediksi Churn pelanggan. Perlu penghitungan ulang kepada model.

# %%
feature_selected
# Out:
# ['PreferredLoginDevice',
#  'CityTier',
#  'PreferredPaymentMode',
#  'NumberOfDeviceRegistered',
#  'PreferedOrderCat',
#  'SatisfactionScore',
#  'MaritalStatus',
#  'Complain',
#  'Tenure',
#  'DaySinceLastOrder',
#  'CashbackAmount']

# %% [markdown]
# 2. Model memprediksi pelanggan Churn terbatas pada rentang value dari tiap-tiap fitur:
# - Tenure: 0-31 bulan
# - DaysSinceLastOrder: 0 - 18 hari
# - CashbackAmount: 110.09 - 324.99
# - PreferredLoginDevice: Mobile Phone & Computer
# - CityTier: Tier 1 - Tier 3
# - PreferredPaymentMethod: Debit Card, Credit Card, COD, E wallet, UPI
# - NumberOfDeviceRegistered: 1 - 6 device
# - PreferedOrderCat: Grocery, Fashion, Laptop & Acc, Mobile Phone, Others
# - SatisfactionScore: Neutral, Dissatisfied, Very_Satisfied, Highly_Dissatisfied, Satisfied
# - MaritalStatus: Single, Married, Divorced
# - Complain: non-Complain, Complain
#
# Apabila ada value diluar dari rentang tersebut, maka model belum bisa menghitung pengaruhnya kepada prediksi Churn pelanggan. Perlu penghitungan ulang kepada model.

# %%
display(df_modelling.describe().T, df_modelling.describe(include='object').T)
# Out:
#                     count        mean        std  min     25%     50%     75%  \
# Tenure             4774.0   10.144323   8.325551  0.0    3.00    9.00   15.00
# DaySinceLastOrder  4774.0    4.433808   3.481735  0.0    2.00    3.00    7.00
# CashbackAmount     4774.0  177.551468  49.528280  0.0  145.83  163.77  197.11
#
#                       max
# Tenure              31.00
# DaySinceLastOrder   18.00
# CashbackAmount     324.99
#                          count unique                    top  freq
# PreferredLoginDevice      4774      2           Mobile Phone  3387
# CityTier                  4774      3                 Tier_1  3101
# PreferredPaymentMode      4774      3      Debit-C & eWallet  2473
# NumberOfDeviceRegistered  4774      4            3-4_Devices  3469
# PreferedOrderCat          4774      4   Laptop, ACC & Others  1965
# SatisfactionScore         4774      4  Satisfied & more_than  1484
# MaritalStatus             4774      3                Married  2524
# ...

# %% [markdown]
# 3. Data imbalance untuk kelompok Churn.
# - Saat ini data imbalance disiasati menggunakan data engineering. Namun tentu hal ini masih memiliki resiko error dan tidak sebaik apabila memiliki data asli yang lebih seimbang.

# %% [markdown]
# ### Recommendation

# %% [markdown]
# **Model Recommendation:**
#
# 1. Model terbaik adalah XGB tanpa Tuning. Performa model dengan tuning mungkin dapat diperbaiki dengan mencari formula yang tepat untuk hyperparam_space.
# 2. Menambahkan fitur-fitur lain dari interaksi pelanggan dengan platform Churn, seperti `Last_Login`, `Total_purchase`, `Total_product_type_purchased`, dll. Fitur-fitur tersebut berpotensi untuk membuat prediksi Churn lebih akurat lagi.
# 3. Perbaikan performa model mungkin dapat coba dilakukan melalui tuning pada 2 dari 3 model teratas yakni, Decision Tree dan Adabost.
# 4. Meningkatkan kualitas data, seperti kurangi missing value, error label, duplikat, dll
# 5. Menambahkan lebih banyak data khususnya untuk kelompok Churn. Hal ini agar kualitas data lebih baik dan meminimalisasi error dari penghitungan

# %% [markdown]
# **Business Recommendation:**
#
# 1. Menggunakan model yang telah dibangun untuk mendeteksi pelanggan existing / baru terhadap kecenderungan mereka untuk Churn. Ini berguna agar e-commerce bisa menarget effortnya dengan tepat. Bagi pelanggan yang terdeteksi berpotensi Churn, maka e-commerce perlu memberikan usaha-usaha agar mereka tetap berbelanja ke platform ini. Salah satunya memberikan promo.
# 1. Selain bersikap reaktif (pemberian promo untuk pelanggan berpotensi Churn), e-commerce bisa melakukan serangkaian usaha lain agar pelanggan bisa loyal secara organik:
# - Pemberian cashback sebagai salah satu skema marketing yang efektif dan menjadi fitur yang penting dalam mencegah terjadinya churn. Cashback secara natural membuat pelanggan lebih bersemangat untuk terus berbelanja di platform sehingga pelanggan melakukan repeat order.
# - Pembuatan skema loyalti ==> hal ini ditujukan untuk membuat engagement level terhadap pelanggan baru. Skema loyalti berupa pemberian promo berdasarkan keaktifan pelanggan sesuai level engagementnya bisa memotivasi pelanggan agar terus berbelanja ke platform secara organik.
# - Peningkatan kualitas layanan Customer Service demi mencegah pelanggan yang melakukan complaint menjadi kecewa terhadap e-commerce dan menjadi Churn. Penyelesaian masalah yang tepat dan efektif tidak hanya menyelesaikan permasalahan namun efektif meredakan perasaan negatif pelanggan.
# - Mempromosikan/perkenalan produk-produk lain yang ada di e-commerce => kecenderungan pelanggan churn adalah pembelian barang mobile phone yang karakteristiknya memang tidak rutin. e-commerce perlu mengenalkan produk-produk lain kepada pelanggan yang membeli barang mobile-phone agar mereka tahu bahwa mereka bisa berbelanja barang lain di platform ini. Penggunaan tools CRM menjadi salah satu opsi.
# - Investasi jangka panjang untuk layanan di kota Tier 3. umumnya masalah pelanggan di tier 3 adalah sedikitnya pilihan penjual dan jauhnya jarak pengiriman dari tempat seller berada. Salah satu solusi yang bisa diatasi dalam jangka panjang adalah lokasi warehouse yang lebih dekat. e-commerce perlu melakukan analisa tambahan dalam penentuan lokasi warehose berdasarkan lokasi pelanggan.
